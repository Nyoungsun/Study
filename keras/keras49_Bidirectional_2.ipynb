# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, GRU
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", data.shape)
print("pre_data.shape: ", pre_data.shape)

x = data[:, :-1] 
y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# x_train = x_train.reshape(-1, 4, 1)
# x_test = x_test.reshape(-1, 4, 1)
# pre_data = pre_data.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# x.shape:  (96, 4) y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)

# %% [markdown]
# # 모델

# %%
model = Sequential()                                                                     
model.add(Bidirectional(LSTM(64, return_sequences=True, activation='relu'), input_shape=(4, 1)))
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 
# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_7 (Bidirectio  (None, 4, 128)           33792
#  nal)
#
#  lstm_12 (LSTM)              (None, 64)                49408
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 91,585
# Trainable params: 91,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 2s 4ms/step - loss: 1279.7648
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 78.9412
# Epoch 3/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2673
# Epoch 4/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4385
# Epoch 5/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5493
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3186
# Epoch 7/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1247
# Epoch 8/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0728
# Epoch 9/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0566
# Epoch 10/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0416
# Epoch 11/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0573
# Epoch 12/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0521
# Epoch 13/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0312
# Epoch 14/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0430
# Epoch 15/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0188
# Epoch 16/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 17/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 18/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 19/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 20/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 22/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0107
# Epoch 23/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 24/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 25/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 26/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 27/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 28/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 29/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 30/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 31/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 32/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 33/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 34/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 35/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 36/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 37/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.3273e-04
# Epoch 38/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 39/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.2202e-04
# Epoch 40/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.1541e-04
# Epoch 41/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9861e-04
# Epoch 42/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.9466e-04
# Epoch 43/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 44/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 45/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 46/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 47/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 48/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 49/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 50/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0110
# Epoch 51/128
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 52/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 53/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 54/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 55/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 56/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 57/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 58/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 59/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 60/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 61/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 62/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0850e-04
# Epoch 63/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 64/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 65/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 66/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 67/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 68/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 69/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0494
# Epoch 70/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0565
# Epoch 71/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0529
# Epoch 72/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1424
# Epoch 73/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2198
# Epoch 74/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3520
# Epoch 75/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1670
# Epoch 76/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2291
# Epoch 77/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0981
# Epoch 78/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3761
# Epoch 79/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4504
# Epoch 80/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1359
# Epoch 81/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 82/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0421
# Epoch 83/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0230
# Epoch 84/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 85/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 86/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 87/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 88/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.7658e-04
# Epoch 89/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0369e-04
# Epoch 90/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 91/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.6379e-04
# Epoch 92/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 93/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 94/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 95/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 96/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0265
# Epoch 97/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 98/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1197e-04
# Epoch 99/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8626e-04
# Epoch 100/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5612e-04
# Epoch 101/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8507e-04
# Epoch 102/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1848e-04
# Epoch 103/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6665e-04
# Epoch 104/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.3155e-04
# Epoch 105/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 106/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8259e-04
# Epoch 107/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1743e-04
# Epoch 108/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 109/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 110/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 111/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 112/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 113/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 114/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 115/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 116/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 117/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1333
# Epoch 118/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0279
# Epoch 119/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9196
# Epoch 120/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6077
# Epoch 121/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2256
# Epoch 122/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2018
# Epoch 123/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7233
# Epoch 124/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6161
# Epoch 125/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4934
# Epoch 126/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1990
# Epoch 127/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.9920
# Epoch 128/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.8527

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 316ms/step - loss: 1.6237
# 1.623733401298523
# prediction result:
#  [[ 97.33168 ]
#  [ 98.28827 ]
#  [ 99.24553 ]
#  [100.203476]
#  [101.16215 ]
#  [102.12154 ]]
