# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %% [markdown]
# # 데이터

# %%
dataset = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

dataset = split_x(dataset, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", dataset.shape)
print("pre_data.shape: ", pre_data.shape)

x = dataset[:, :-1] 
y = dataset[:, -1]

pre_data = pre_data[:, :-1] 
print("pre_data : ", pre_data)
print("pre_data.shape : ", pre_data.shape)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x = x.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# pre_data :  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# pre_data.shape :  (6, 4)
# x.shape:  (96, 4) y.shape:  (96,)

# %%
model = Sequential()                                                                      # (None, 3, 1)
model.add(LSTM(units = 64, input_shape=(4, 1), return_sequences=True, activation='relu')) # model.add(SimpleRNN(units = 64, input_length = 3, input_dim = 1)) # model.add(SimpleRNN(units = 64, input_shape=(3, 1)))
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(16))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 4, 64)             16896
#
#  lstm_17 (LSTM)              (None, 64)                33024
#
#  dense_36 (Dense)            (None, 64)                4160
#
#  dense_37 (Dense)            (None, 64)                4160
#
#  dense_38 (Dense)            (None, 16)                1040
#
#  dense_39 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 59,297
# Trainable params: 59,297
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x, y, epochs=128)
# Out:
# Epoch 1/128
# 3/3 [==============================] - 1s 22ms/step - loss: 3498.5203
# Epoch 2/128
# 3/3 [==============================] - 0s 20ms/step - loss: 2998.8508
# Epoch 3/128
# 3/3 [==============================] - 0s 17ms/step - loss: 2054.3569
# Epoch 4/128
# 3/3 [==============================] - 0s 19ms/step - loss: 647.6399
# Epoch 5/128
# 3/3 [==============================] - 0s 20ms/step - loss: 246.0428
# Epoch 6/128
# 3/3 [==============================] - 0s 17ms/step - loss: 401.2574
# Epoch 7/128
# 3/3 [==============================] - 0s 17ms/step - loss: 36.1496
# Epoch 8/128
# 3/3 [==============================] - 0s 17ms/step - loss: 112.7297
# Epoch 9/128
# 3/3 [==============================] - 0s 17ms/step - loss: 119.9655
# Epoch 10/128
# 3/3 [==============================] - 0s 16ms/step - loss: 25.8327
# Epoch 11/128
# 3/3 [==============================] - 0s 16ms/step - loss: 32.6941
# Epoch 12/128
# 3/3 [==============================] - 0s 17ms/step - loss: 27.3018
# Epoch 13/128
# 3/3 [==============================] - 0s 19ms/step - loss: 3.4664
# Epoch 14/128
# 3/3 [==============================] - 0s 19ms/step - loss: 12.0532
# Epoch 15/128
# 3/3 [==============================] - 0s 19ms/step - loss: 9.1062
# Epoch 16/128
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7093
# Epoch 17/128
# 3/3 [==============================] - 0s 16ms/step - loss: 4.0662
# Epoch 18/128
# 3/3 [==============================] - 0s 15ms/step - loss: 4.0919
# Epoch 19/128
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0010
# Epoch 20/128
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8921
# Epoch 21/128
# 3/3 [==============================] - 0s 15ms/step - loss: 1.7848
# Epoch 22/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7303
# Epoch 23/128
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0162
# Epoch 24/128
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9657
# Epoch 25/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5163
# Epoch 26/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6423
# Epoch 27/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5180
# Epoch 28/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3481
# Epoch 29/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3901
# Epoch 30/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2919
# Epoch 31/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2313
# Epoch 32/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2258
# Epoch 33/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1715
# Epoch 34/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1504
# Epoch 35/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1186
# Epoch 36/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1031
# Epoch 37/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0891
# Epoch 38/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0792
# Epoch 39/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0705
# Epoch 40/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0632
# Epoch 41/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0567
# Epoch 42/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0509
# Epoch 43/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0469
# Epoch 44/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0432
# Epoch 45/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0386
# Epoch 46/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0354
# Epoch 47/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0330
# Epoch 48/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0304
# Epoch 49/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0277
# Epoch 50/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0258
# Epoch 51/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0239
# Epoch 52/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0223
# Epoch 53/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0206
# Epoch 54/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0200
# Epoch 55/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0185
# Epoch 56/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0177
# Epoch 57/128
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0170
# Epoch 58/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0154
# Epoch 59/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0148
# Epoch 60/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0140
# Epoch 61/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0134
# Epoch 62/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0126
# Epoch 63/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0121
# Epoch 64/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0116
# Epoch 65/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0111
# Epoch 66/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0106
# Epoch 67/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0102
# Epoch 68/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0097
# Epoch 69/128
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0096
# Epoch 70/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0092
# Epoch 71/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0089
# Epoch 72/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083
# Epoch 73/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0078
# Epoch 74/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0077
# Epoch 75/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0071
# Epoch 76/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0070
# Epoch 77/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0068
# Epoch 78/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0063
# Epoch 79/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0060
# Epoch 80/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0059
# Epoch 81/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0058
# Epoch 82/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0054
# Epoch 83/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0052
# Epoch 84/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051
# Epoch 85/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0049
# Epoch 86/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0047
# Epoch 87/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0045
# Epoch 88/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044
# Epoch 89/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0041
# Epoch 90/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0038
# Epoch 91/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 92/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0036
# Epoch 93/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0035
# Epoch 94/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 95/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0032
# Epoch 96/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0030
# Epoch 97/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0030
# Epoch 98/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0028
# Epoch 99/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0027
# Epoch 100/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0025
# Epoch 101/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0025
# Epoch 102/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 103/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0023
# Epoch 104/128
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0022
# Epoch 105/128
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0021
# Epoch 106/128
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0019
# Epoch 107/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020
# Epoch 108/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018
# Epoch 109/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017
# Epoch 110/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0016
# Epoch 111/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0019
# Epoch 112/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 113/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015
# Epoch 114/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 115/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0013
# Epoch 116/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 117/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 118/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 119/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 120/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 121/128
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 122/128
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0011
# Epoch 123/128
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0011
# Epoch 124/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0010
# Epoch 125/128
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0010
# Epoch 126/128
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0010
# Epoch 127/128
# 3/3 [==============================] - 0s 16ms/step - loss: 9.7432e-04
# Epoch 128/128
# 3/3 [==============================] - 0s 17ms/step - loss: 9.6248e-04

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x, y)
print(loss)

y_predict = np.array(pre_data)

result = model.predict(y_predict)

print('prediction result:\n', result)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 9.0540e-04
# 0.0009053995017893612
# prediction result:
#  [[100.02192 ]
#  [101.02184 ]
#  [102.02168 ]
#  [103.02142 ]
#  [104.021065]
#  [105.02061 ]]
