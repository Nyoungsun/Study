# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", data.shape)
print("pre_data.shape: ", pre_data.shape)

x = data[:, :-1] 
y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# x_train = x_train.reshape(-1, 4, 1)
# x_test = x_test.reshape(-1, 4, 1)
# pre_data = pre_data.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# x.shape:  (96, 4) y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)

# %%
model = Sequential()                                                                     
model.add(LSTM(units = 64, input_shape=(4, 1), return_sequences=True, activation='relu')) 
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 4, 64)             16896
#
#  lstm_23 (LSTM)              (None, 64)                33024
#
#  dense_43 (Dense)            (None, 64)                4160
#
#  dense_44 (Dense)            (None, 64)                4160
#
#  dense_45 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 58,305
# Trainable params: 58,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 1s 3ms/step - loss: 1841.7744
# Epoch 2/128
# 23/23 [==============================] - 0s 2ms/step - loss: 31.8484
# Epoch 3/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7493
# Epoch 4/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3929
# Epoch 5/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7203
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3899
# Epoch 7/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2988
# Epoch 8/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1803
# Epoch 9/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1081
# Epoch 10/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0894
# Epoch 11/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0669
# Epoch 12/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0537
# Epoch 13/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0454
# Epoch 14/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0387
# Epoch 15/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0260
# Epoch 16/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0185
# Epoch 17/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 18/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0145
# Epoch 19/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 20/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0106
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0144
# Epoch 22/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 23/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 24/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 25/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 26/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 27/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 28/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 29/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 30/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 31/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 32/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 33/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 34/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 35/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 36/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 37/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 38/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 39/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 40/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 41/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 42/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 43/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 44/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7557e-04
# Epoch 45/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.0423e-04
# Epoch 46/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9763e-04
# Epoch 47/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.5609e-04
# Epoch 48/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7188e-04
# Epoch 49/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3833e-04
# Epoch 50/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1833e-04
# Epoch 51/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2049e-04
# Epoch 52/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4254e-04
# Epoch 53/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3765e-04
# Epoch 54/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0470e-04
# Epoch 55/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 56/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4669e-04
# Epoch 57/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.0763e-04
# Epoch 58/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5201e-04
# Epoch 59/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.7710e-04
# Epoch 60/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5967e-04
# Epoch 61/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5961e-04
# Epoch 62/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3006e-04
# Epoch 63/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5570e-04
# Epoch 64/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 65/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5592e-04
# Epoch 66/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2840e-04
# Epoch 67/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3191e-04
# Epoch 68/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3367e-04
# Epoch 69/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.0869e-04
# Epoch 70/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8645e-04
# Epoch 71/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 72/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 73/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 74/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 75/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7806e-04
# Epoch 76/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8580e-04
# Epoch 77/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6645e-04
# Epoch 78/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 79/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 80/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0661
# Epoch 81/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0621
# Epoch 82/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 83/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 84/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0119
# Epoch 85/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0392
# Epoch 86/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2041
# Epoch 87/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1881
# Epoch 88/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0350
# Epoch 89/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2876
# Epoch 90/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6410
# Epoch 91/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4885
# Epoch 92/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8615
# Epoch 93/128
# 23/23 [==============================] - 0s 3ms/step - loss: 16.3814
# Epoch 94/128
# 23/23 [==============================] - 0s 3ms/step - loss: 12.3793
# Epoch 95/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6136
# Epoch 96/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7650
# Epoch 97/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0220
# Epoch 98/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 99/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0197
# Epoch 100/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 101/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 102/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7465e-04
# Epoch 103/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6768e-04
# Epoch 104/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5289e-04
# Epoch 105/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.0737e-04
# Epoch 106/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1414e-04
# Epoch 107/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0724e-04
# Epoch 108/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.0073e-04
# Epoch 109/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6409e-04
# Epoch 110/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.3278e-04
# Epoch 111/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8449e-04
# Epoch 112/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8965e-04
# Epoch 113/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6568e-04
# Epoch 114/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4856e-04
# Epoch 115/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5143e-04
# Epoch 116/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8377e-04
# Epoch 117/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4632e-04
# Epoch 118/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6167e-04
# Epoch 119/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.0521e-04
# Epoch 120/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.7362e-04
# Epoch 121/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.8381e-04
# Epoch 122/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4075e-04
# Epoch 123/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.0364e-04
# Epoch 124/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8207e-04
# Epoch 125/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2631e-04
# Epoch 126/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5827e-04
# Epoch 127/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.7637e-04
# Epoch 128/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3384e-04

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

y_predict = np.array(pre_data)

result = model.predict(y_predict)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0043
# 0.004251280799508095
# prediction result:
#  [[100.050575]
#  [101.053116]
#  [102.05581 ]
#  [103.05859 ]
#  [104.06151 ]
#  [105.0645  ]]
