# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", data.shape)
print("pre_data.shape: ", pre_data.shape)

x = data[:, :-1] 
y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# x_train = x_train.reshape(-1, 4, 1)
# x_test = x_test.reshape(-1, 4, 1)
# pre_data = pre_data.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# x.shape:  (96, 4) y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)

# %%
model = Sequential()                                                                     
model.add(LSTM(units = 64, input_shape=(4, 1), return_sequences=True, activation='relu')) 
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 4, 64)             16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 58,305
# Trainable params: 58,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 1s 4ms/step - loss: 1469.8639
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 20.3456
# Epoch 3/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4580
# Epoch 4/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0262
# Epoch 5/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3863
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2392
# Epoch 7/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1361
# Epoch 8/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1047
# Epoch 9/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0813
# Epoch 10/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0673
# Epoch 11/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 12/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0371
# Epoch 13/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 14/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0257
# Epoch 15/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0247
# Epoch 16/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 17/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 18/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0171
# Epoch 19/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0215
# Epoch 20/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 22/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 23/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 24/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 25/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096
# Epoch 26/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 27/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 28/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 29/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 30/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 31/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 32/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 33/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 34/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 35/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 36/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 37/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 38/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 39/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 40/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 41/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 42/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 43/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 44/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 45/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 46/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 47/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 48/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0367
# Epoch 49/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 50/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 51/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 52/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0129
# Epoch 53/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 54/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 55/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 56/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 57/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 58/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 59/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 60/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 61/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 62/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 63/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 64/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 65/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.6587e-04
# Epoch 66/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.0330e-04
# Epoch 67/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4648e-04
# Epoch 68/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 69/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 70/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 71/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 72/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 73/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 74/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 75/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 76/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7403e-04
# Epoch 77/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.9159e-04
# Epoch 78/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 79/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 80/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 81/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 82/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 83/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 84/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 85/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 86/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 87/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 88/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0466
# Epoch 89/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1413
# Epoch 90/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2185
# Epoch 91/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2389
# Epoch 92/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2078
# Epoch 93/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1759
# Epoch 94/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 95/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0377
# Epoch 96/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1023
# Epoch 97/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0663
# Epoch 98/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0581
# Epoch 99/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0662
# Epoch 100/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1356
# Epoch 101/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2199
# Epoch 102/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0915
# Epoch 103/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0279
# Epoch 104/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0819
# Epoch 105/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0339
# Epoch 106/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0097
# Epoch 107/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 108/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 109/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 110/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0264
# Epoch 111/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2711
# Epoch 112/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2824
# Epoch 113/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1035
# Epoch 114/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5589
# Epoch 115/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2951
# Epoch 116/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4287
# Epoch 117/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1935
# Epoch 118/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0653
# Epoch 119/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 120/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 121/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0289
# Epoch 122/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 123/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1451
# Epoch 124/128
# 23/23 [==============================] - 0s 3ms/step - loss: 52.3830
# Epoch 125/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3983
# Epoch 126/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4827
# Epoch 127/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1459
# Epoch 128/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1557

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0343
# 0.03433776646852493
# prediction result:
#  [[100.4112  ]
#  [101.42638 ]
#  [102.44158 ]
#  [103.456825]
#  [104.47211 ]
#  [105.4874  ]]
