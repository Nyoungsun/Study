# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. 데이터

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

print(x_train.shape, y_train.shape) 
print(x_test.shape, y_test.shape)   

print(x_train[0], y_train[0])       # 데이터 확인
plt.imshow(x_train[0], 'gray')      # 이미지 확인
plt.show()

# ---------- 전처리 (4차원으로 변환) ---------- #
x_train = x_train.reshape(60000, 28, 28, 1)
x_test = x_test.reshape(10000, 28, 28, 1)

print(np.unique(y_train, return_counts = True))
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4208\745491284.py in <module>
# ----> 1 (x_train, y_train), (x_test, y_test) = cifar100.load_data()
#       2
#       3 print(x_train.shape, y_train.shape)
#       4 print(x_test.shape, y_test.shape)
#       5
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\datasets\cifar100.py in load_data(label_mode)
#      80
#      81   fpath = os.path.join(path, 'train')
# ---> 82   x_train, y_train = load_batch(fpath, label_key=label_mode + '_labels')
#      83
#      84   fpath = os.path.join(path, 'test')
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\datasets\cifar.py in load_batch(fpath, label_key)
#      30   """
#      31   with open(fpath, 'rb') as f:
# ---> 32     d = cPickle.load(f, encoding='bytes')
#      33     # decode utf8
#      34     d_decoded = {}
#
# UnpicklingError: pickle data was truncated

# %% [markdown]
# # 2. 모델

# %%
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=(2,2), input_shape=(28,28,1), padding='same', activation='relu')) # output shape = 28, 28, 128
model.add(MaxPooling2D())                                                                                   # output shape = 14, 14, 128 
model.add(Conv2D(filters=64, kernel_size=(2,2), padding='same', activation='relu'))     
model.add(Conv2D(filters=32, kernel_size=(2,2), activation='relu'))                    
model.add(Conv2D(filters=16, kernel_size=(2,2), activation='relu'))
model.add(MaxPooling2D())                                                                                   # output shape = 14, 14, 128 
model.add(Conv2D(filters=8, kernel_size=(2,2), activation='relu'))
model.add(Flatten())
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 64)        16448
#
#  conv2d_12 (Conv2D)          (None, 13, 13, 32)        8224
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 16)        2064
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 8)           520
#
#  flatten_2 (Flatten)         (None, 200)               0
#
#  dense_4 (Dense)             (None, 16)                3216
#
#  dense_5 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 30,962
# Trainable params: 30,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 컴파일 및 훈련

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics='acc') # one-hot encoding 하지 않아도 되는 데이터이므로 loss= sparse_categorical_crossentropy

path = 'C:/study/keras/keras_save/MCP/'
MCP = ModelCheckpoint(monitor='acc', mode='auto', save_best_only=True, filepath=path+'keras34_1_mnist.hdf5') 
ES = EarlyStopping(monitor='acc', mode='auto', patience=4, restore_best_weights=True) 
model.fit(x_train, y_train, epochs=32, batch_size=256, validation_split=0.1, callbacks=[ES, MCP])
# Out:
# Epoch 1/32
# 211/211 [==============================] - 3s 10ms/step - loss: 1.1376 - acc: 0.6607 - val_loss: 0.2184 - val_acc: 0.9350
# Epoch 2/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.2018 - acc: 0.9407 - val_loss: 0.1145 - val_acc: 0.9643
# Epoch 3/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.1257 - acc: 0.9615 - val_loss: 0.0975 - val_acc: 0.9705
# Epoch 4/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0974 - acc: 0.9708 - val_loss: 0.0750 - val_acc: 0.9797
# Epoch 5/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0780 - acc: 0.9760 - val_loss: 0.0702 - val_acc: 0.9802
# Epoch 6/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.0653 - acc: 0.9794 - val_loss: 0.0626 - val_acc: 0.9813
# Epoch 7/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.0597 - acc: 0.9812 - val_loss: 0.0685 - val_acc: 0.9830
# Epoch 8/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.0519 - acc: 0.9827 - val_loss: 0.0626 - val_acc: 0.9828
# Epoch 9/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.0450 - acc: 0.9862 - val_loss: 0.0623 - val_acc: 0.9808
# Epoch 10/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0420 - acc: 0.9865 - val_loss: 0.0621 - val_acc: 0.9853
# Epoch 11/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0396 - acc: 0.9870 - val_loss: 0.0602 - val_acc: 0.9832
# Epoch 12/32
# 211/211 [==============================] - 2s 10ms/step - loss: 0.0352 - acc: 0.9880 - val_loss: 0.0499 - val_acc: 0.9852
# Epoch 13/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0321 - acc: 0.9895 - val_loss: 0.0644 - val_acc: 0.9843
# Epoch 14/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0322 - acc: 0.9890 - val_loss: 0.0539 - val_acc: 0.9847
# Epoch 15/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0287 - acc: 0.9906 - val_loss: 0.0554 - val_acc: 0.9858
# Epoch 16/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0253 - acc: 0.9914 - val_loss: 0.0630 - val_acc: 0.9845
# Epoch 17/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0269 - acc: 0.9910 - val_loss: 0.0557 - val_acc: 0.9875
# Epoch 18/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0213 - acc: 0.9932 - val_loss: 0.0548 - val_acc: 0.9857
# Epoch 19/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0233 - acc: 0.9920 - val_loss: 0.0622 - val_acc: 0.9850
# Epoch 20/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0228 - acc: 0.9922 - val_loss: 0.0594 - val_acc: 0.9868
# Epoch 21/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0202 - acc: 0.9926 - val_loss: 0.0639 - val_acc: 0.9837
# Epoch 22/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0555 - val_acc: 0.9862
# Epoch 23/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0203 - acc: 0.9928 - val_loss: 0.0608 - val_acc: 0.9860
# Epoch 24/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0160 - acc: 0.9948 - val_loss: 0.0551 - val_acc: 0.9888
# Epoch 25/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0152 - acc: 0.9946 - val_loss: 0.0663 - val_acc: 0.9838
# Epoch 26/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0200 - acc: 0.9932 - val_loss: 0.0499 - val_acc: 0.9875
# Epoch 27/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0134 - acc: 0.9954 - val_loss: 0.0523 - val_acc: 0.9885
# Epoch 28/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0163 - acc: 0.9944 - val_loss: 0.0558 - val_acc: 0.9850
# Epoch 29/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0183 - acc: 0.9937 - val_loss: 0.0613 - val_acc: 0.9865
# Epoch 30/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0120 - acc: 0.9956 - val_loss: 0.0639 - val_acc: 0.9860
# Epoch 31/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0145 - acc: 0.9950 - val_loss: 0.0625 - val_acc: 0.9878
# Epoch 32/32
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0103 - acc: 0.9963 - val_loss: 0.0765 - val_acc: 0.9845

# %% [markdown]
# # 4. 평가 및 예측

# %%
metric = model.evaluate(x_test, y_test) # compile에서 metrics = acc를 지정했으므로 evaluate는 값을 배열 형태로 2개 반환함
print('loss: ', metric[0], 'acc: ', metric[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0732 - acc: 0.9822
# loss:  0.07318046689033508 acc:  0.982200026512146
