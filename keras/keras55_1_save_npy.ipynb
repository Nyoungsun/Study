# %% [markdown]
#  # 데이터

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data_Gen = ImageDataGenerator (
    rescale = 1./255, 
    # horizontal_flip = True,         # 수평선을 기준으로 반전
    # vertical_flip = True,           # 수직선을 기준으로 반전
    # width_shift_range = 0.1,        # 10% 만큼 가로 이동
    # height_shift_range = 0.1,       # 10% 만큼 세로 이동
    # rotation_range = 5,             # 회전
    # zoom_range = 0.7,               # 확대
    # shear_range = 0.7,              # 엇갈림
    # fill_mode = 'nearest'           # 축 이동을 했을 때 비는 부분을 가까운 값으로 채운다.
)

test_data_Gen = ImageDataGenerator (
    rescale = 1./255                # 테스트 데이터는 리스케일링만 한다.: 평가에 쓰이는 테스트 데이터는 증폭시키지 않은 원 데이터 사용
)

xy_train = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/train',
    target_size=(200,200),
    batch_size=1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    # class_mode='categorical',       # one-hot
    color_mode='grayscale',
    shuffle=True
)

# ad(alzheimer disease) = 0, normal = 1  
# x = (160, 150, 150, 1), y = (160,) → 흑백 image 
# 160장 중에 ad, normal 각 80장씩
# np.unique = 0, 1

xy_test = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/test',
    target_size=(200,200),
    batch_size=1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True
)

# print(xy_train, '\n', xy_test)    # <keras.preprocessing.image.DirectoryIterator object at 0x000002862718CAC0>
# print(xy_train[0])                # x data와 y data 개수, y data 개수 = batch_size 개수 만큼
# print(xy_train[0][0])
# print(xy_train[0][1])
print(xy_train[0][0].shape)         # x (10 = batch_size)
print(xy_train[0][1].shape)         # y

# batch_size를 전체 데이터보다 최대한 크게 끔 지정하면 전체 데이터의 개수를 알 수 있다.
 
print(type(xy_train))        
print(type(xy_train[0]))             # 튜플은 변경 불가 
print(type(xy_train[0][0]))
print(type(xy_train[0][1]))
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# (160, 200, 200, 1)
# (160,)
# <class 'keras.preprocessing.image.DirectoryIterator'>
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# # 수치화된 원본 이미지 저장

# %%
np.save('C:/study/keras/keras_data/brain/brain_x_train.npy', arr=xy_train[0][0])
np.save('C:/study/keras/keras_data/brain/brain_y_train.npy', arr=xy_train[0][1])

np.save('C:/study/keras/keras_data/brain/brain_x_test.npy', arr=xy_test[0][0])
np.save('C:/study/keras/keras_data/brain/brain_y_test.npy', arr=xy_test[0][1])

# %% [markdown]
# # 변환 후 이미지

# %%
import matplotlib.pyplot as plt

img = xy_train[0] # img = xy_train.__getitem__(0)
plt.figure(figsize=(20, 5))
for i, img in enumerate(img[0]):
    plt.subplot(1, 10, i+1)
    plt.title('%.2f' % img[1][i])
    plt.axis('off') # 축 표시 X
    plt.imshow(img.squeeze(), 'gray') #차원 = 1인 차원을 제거
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16924\4032746892.py in <module>
#       4 plt.figure(figsize=(20, 5))
#       5 for i, img in enumerate(img[0]):
# ----> 6     plt.subplot(1, 10, i+1)
#       7     plt.title('%.2f' % img[1][i])
#       8     plt.axis('off') # 축 표시 X
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1262
#    1263     # First, search for an existing subplot with a matching spec.
# -> 1264     key = SubplotSpec._from_subplot_args(fig, args)
#    1265
#    1266     for ax in fig.axes:
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     610         else:
#     611             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 612                 raise ValueError(
#     613                     f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     614             i = j = num
#
# ValueError: num must be 1 <= num <= 10, not 11
