# %% [markdown]
# # 데이터

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data_Gen = ImageDataGenerator (
    rescale = 1./255, 
    horizontal_flip = True,         # 수평선을 기준으로 반전
    vertical_flip = True,           # 수직선을 기준으로 반전
    width_shift_range = 0.1,        # 10% 만큼 가로 이동
    height_shift_range = 0.1,       # 10% 만큼 세로 이동
    rotation_range = 5,             # 회전
    zoom_range = 0.7,               # 확대
    shear_range = 0.7,              # 엇갈림
    fill_mode = 'nearest'           # 축 이동을 했을 때 비는 부분을 가까운 값으로 채운다.
)

test_data_Gen = ImageDataGenerator (
    rescale = 1./255                # 테스트 데이터는 리스케일링만 한다.: 평가에 쓰이는 테스트 데이터는 증폭시키지 않은 원 데이터 사용
)

xy_train = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/train',
    target_size=(100,100),
    batch_size= 1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True
)

# ad(alzheimer disease) = 0, normal = 1  
# x = (160, 150, 150, 1), y = (160,) → 흑백 image 
# 160장 중에 ad, normal 각 80장씩
# np.unique = 0, 1

xy_test = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/test',
    target_size=(100,100),
    batch_size=1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True
)

# print(xy_train, '\n', xy_test)    # <keras.preprocessing.image.DirectoryIterator object at 0x000002862718CAC0> 
# print(xy_train[0])                # x data와 y data 개수, y data 개수 = batch_size 개수 만큼
# print(xy_train[0][0])
# print(xy_train[0][1])
print(len(xy_train[0]))  
print(xy_train[0][0].shape)         # x (10 = batch_size)
print(xy_train[0][1].shape)         # y

# batch_size를 전체 데이터보다 최대한 크게 끔 지정하면 전체 데이터의 개수를 알 수 있다.
print(type(xy_train)) 
print(type(xy_train[0]))             # 튜플은 변경 불가
print(type(xy_train[0][0]))          # x
print(type(xy_train[0][1]))          # y
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# 2
# (160, 100, 100, 1)
# (160,)
# <class 'keras.preprocessing.image.DirectoryIterator'>
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
#  # 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten

model = Sequential()
model.add(Conv2D(64, (2,2), input_shape=(100, 100, 1), activation='relu'))
model.add(Conv2D(64, (2,2), activation='relu'))
model.add(Conv2D(64, (2,2), activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
#  # 컴파일, 훈련

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics='acc')
# hist = model.fit_generator(xy_train, steps_per_epoch=16, epochs=128, validation_data=xy_test, validation_steps=4)  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수
hist = model.fit(xy_train[0][0], xy_train[0][1], epochs=128, batch_size=10, validation_data=(xy_test[0][0], xy_test[0][1]))  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수

acc = hist.history['acc']
val_acc = hist.history['val_acc']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
print('acc: ', acc[-1])
print('loss: ', loss[-1])
print('val_acc: ', val_acc[-1])
print('val_loss: ', val_loss[-1])
# Out:
# Epoch 1/128
# 16/16 [==============================] - 3s 21ms/step - loss: 0.7754 - acc: 0.4750 - val_loss: 0.6897 - val_acc: 0.5083
# Epoch 2/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6930 - acc: 0.5312 - val_loss: 0.6878 - val_acc: 0.5333
# Epoch 3/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6533 - acc: 0.5875 - val_loss: 0.7032 - val_acc: 0.5333
# Epoch 4/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5699 - acc: 0.7688 - val_loss: 0.6824 - val_acc: 0.6000
# Epoch 5/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3917 - acc: 0.8875 - val_loss: 0.8667 - val_acc: 0.5667
# Epoch 6/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3293 - acc: 0.8500 - val_loss: 0.6555 - val_acc: 0.6250
# Epoch 7/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1062 - acc: 0.9812 - val_loss: 1.2864 - val_acc: 0.5667
# Epoch 8/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0643 - acc: 0.9812 - val_loss: 1.0793 - val_acc: 0.5583
# Epoch 9/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1443 - acc: 0.9438 - val_loss: 1.2165 - val_acc: 0.6083
# Epoch 10/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2284 - acc: 0.9125 - val_loss: 0.8963 - val_acc: 0.5250
# Epoch 11/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0431 - acc: 0.9937 - val_loss: 1.3939 - val_acc: 0.5000
# Epoch 12/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0170 - acc: 1.0000 - val_loss: 1.2410 - val_acc: 0.5333
# Epoch 13/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 1.5653 - val_acc: 0.5583
# Epoch 14/128
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.4569 - val_acc: 0.5583
# Epoch 15/128
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 1.4993 - val_acc: 0.5583
# Epoch 16/128
# 16/16 [==============================] - 0s 13ms/step - loss: 6.5414e-04 - acc: 1.0000 - val_loss: 1.5452 - val_acc: 0.5500
# Epoch 17/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.9659e-04 - acc: 1.0000 - val_loss: 1.5446 - val_acc: 0.5583
# Epoch 18/128
# 16/16 [==============================] - 0s 13ms/step - loss: 2.8905e-04 - acc: 1.0000 - val_loss: 1.5896 - val_acc: 0.5667
# Epoch 19/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.9079e-04 - acc: 1.0000 - val_loss: 1.6265 - val_acc: 0.5500
# Epoch 20/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.4336e-04 - acc: 1.0000 - val_loss: 1.6622 - val_acc: 0.5917
# Epoch 21/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.0374e-04 - acc: 1.0000 - val_loss: 1.6744 - val_acc: 0.5917
# Epoch 22/128
# 16/16 [==============================] - 0s 14ms/step - loss: 8.1330e-05 - acc: 1.0000 - val_loss: 1.7110 - val_acc: 0.5833
# Epoch 23/128
# 16/16 [==============================] - 0s 13ms/step - loss: 5.6869e-05 - acc: 1.0000 - val_loss: 1.7970 - val_acc: 0.5750
# Epoch 24/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.6239e-05 - acc: 1.0000 - val_loss: 1.8057 - val_acc: 0.5917
# Epoch 25/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.7813e-05 - acc: 1.0000 - val_loss: 1.8761 - val_acc: 0.5750
# Epoch 26/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.4102e-05 - acc: 1.0000 - val_loss: 1.8808 - val_acc: 0.6000
# Epoch 27/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.1001e-05 - acc: 1.0000 - val_loss: 1.9454 - val_acc: 0.5750
# Epoch 28/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.4237e-05 - acc: 1.0000 - val_loss: 1.9522 - val_acc: 0.6000
# Epoch 29/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.0088e-05 - acc: 1.0000 - val_loss: 1.9847 - val_acc: 0.5667
# Epoch 30/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.8131e-05 - acc: 1.0000 - val_loss: 2.0008 - val_acc: 0.5750
# Epoch 31/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.6742e-05 - acc: 1.0000 - val_loss: 2.0146 - val_acc: 0.5833
# Epoch 32/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.4316e-05 - acc: 1.0000 - val_loss: 2.0500 - val_acc: 0.5750
# Epoch 33/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.2768e-05 - acc: 1.0000 - val_loss: 2.0694 - val_acc: 0.5750
# Epoch 34/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.1845e-05 - acc: 1.0000 - val_loss: 2.0898 - val_acc: 0.5750
# Epoch 35/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.1016e-05 - acc: 1.0000 - val_loss: 2.1008 - val_acc: 0.5750
# Epoch 36/128
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0567e-05 - acc: 1.0000 - val_loss: 2.1268 - val_acc: 0.5667
# Epoch 37/128
# 16/16 [==============================] - 0s 20ms/step - loss: 1.0153e-05 - acc: 1.0000 - val_loss: 2.1288 - val_acc: 0.5833
# Epoch 38/128
# 16/16 [==============================] - 0s 16ms/step - loss: 8.8355e-06 - acc: 1.0000 - val_loss: 2.1637 - val_acc: 0.5750
# Epoch 39/128
# 16/16 [==============================] - 0s 16ms/step - loss: 7.0534e-06 - acc: 1.0000 - val_loss: 2.1633 - val_acc: 0.5750
# Epoch 40/128
# 16/16 [==============================] - 0s 16ms/step - loss: 6.8768e-06 - acc: 1.0000 - val_loss: 2.1764 - val_acc: 0.5750
# Epoch 41/128
# 16/16 [==============================] - 0s 16ms/step - loss: 6.2289e-06 - acc: 1.0000 - val_loss: 2.2032 - val_acc: 0.5750
# Epoch 42/128
# 16/16 [==============================] - 0s 17ms/step - loss: 5.6687e-06 - acc: 1.0000 - val_loss: 2.2089 - val_acc: 0.5750
# Epoch 43/128
# 16/16 [==============================] - 0s 16ms/step - loss: 5.3775e-06 - acc: 1.0000 - val_loss: 2.2281 - val_acc: 0.5750
# Epoch 44/128
# 16/16 [==============================] - 0s 17ms/step - loss: 4.9716e-06 - acc: 1.0000 - val_loss: 2.2353 - val_acc: 0.5750
# Epoch 45/128
# 16/16 [==============================] - 0s 17ms/step - loss: 4.7123e-06 - acc: 1.0000 - val_loss: 2.2447 - val_acc: 0.5750
# Epoch 46/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.3046e-06 - acc: 1.0000 - val_loss: 2.2597 - val_acc: 0.5750
# Epoch 47/128
# 16/16 [==============================] - 0s 19ms/step - loss: 4.1962e-06 - acc: 1.0000 - val_loss: 2.2676 - val_acc: 0.5750
# Epoch 48/128
# 16/16 [==============================] - 0s 16ms/step - loss: 3.8200e-06 - acc: 1.0000 - val_loss: 2.2837 - val_acc: 0.5750
# Epoch 49/128
# 16/16 [==============================] - 0s 15ms/step - loss: 3.6699e-06 - acc: 1.0000 - val_loss: 2.3005 - val_acc: 0.5750
# Epoch 50/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.4424e-06 - acc: 1.0000 - val_loss: 2.3005 - val_acc: 0.5750
# Epoch 51/128
# 16/16 [==============================] - 0s 14ms/step - loss: 3.3398e-06 - acc: 1.0000 - val_loss: 2.3182 - val_acc: 0.5750
# Epoch 52/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.0086e-06 - acc: 1.0000 - val_loss: 2.3259 - val_acc: 0.5750
# Epoch 53/128
# 16/16 [==============================] - 0s 17ms/step - loss: 2.9701e-06 - acc: 1.0000 - val_loss: 2.3365 - val_acc: 0.5750
# Epoch 54/128
# 16/16 [==============================] - 0s 14ms/step - loss: 2.7616e-06 - acc: 1.0000 - val_loss: 2.3498 - val_acc: 0.5750
# Epoch 55/128
# 16/16 [==============================] - 0s 13ms/step - loss: 2.6711e-06 - acc: 1.0000 - val_loss: 2.3562 - val_acc: 0.5750
# Epoch 56/128
# 16/16 [==============================] - 0s 14ms/step - loss: 2.5159e-06 - acc: 1.0000 - val_loss: 2.3669 - val_acc: 0.5750
# Epoch 57/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.4058e-06 - acc: 1.0000 - val_loss: 2.3749 - val_acc: 0.5750
# Epoch 58/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.2992e-06 - acc: 1.0000 - val_loss: 2.3825 - val_acc: 0.5750
# Epoch 59/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.1693e-06 - acc: 1.0000 - val_loss: 2.3925 - val_acc: 0.5750
# Epoch 60/128
# 16/16 [==============================] - 0s 12ms/step - loss: 2.1049e-06 - acc: 1.0000 - val_loss: 2.3982 - val_acc: 0.5750
# Epoch 61/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.9993e-06 - acc: 1.0000 - val_loss: 2.4125 - val_acc: 0.5750
# Epoch 62/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.9056e-06 - acc: 1.0000 - val_loss: 2.4162 - val_acc: 0.5750
# Epoch 63/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.8419e-06 - acc: 1.0000 - val_loss: 2.4223 - val_acc: 0.5750
# Epoch 64/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.7666e-06 - acc: 1.0000 - val_loss: 2.4303 - val_acc: 0.5750
# Epoch 65/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.7247e-06 - acc: 1.0000 - val_loss: 2.4410 - val_acc: 0.5750
# Epoch 66/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.6507e-06 - acc: 1.0000 - val_loss: 2.4491 - val_acc: 0.5750
# Epoch 67/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.7169e-06 - acc: 1.0000 - val_loss: 2.4638 - val_acc: 0.5917
# Epoch 68/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.5419e-06 - acc: 1.0000 - val_loss: 2.4594 - val_acc: 0.5750
# Epoch 69/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.4493e-06 - acc: 1.0000 - val_loss: 2.4706 - val_acc: 0.5750
# Epoch 70/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.4037e-06 - acc: 1.0000 - val_loss: 2.4791 - val_acc: 0.5750
# Epoch 71/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.3448e-06 - acc: 1.0000 - val_loss: 2.4849 - val_acc: 0.5750
# Epoch 72/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.2991e-06 - acc: 1.0000 - val_loss: 2.4930 - val_acc: 0.5750
# Epoch 73/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.2540e-06 - acc: 1.0000 - val_loss: 2.5017 - val_acc: 0.5750
# Epoch 74/128
# 16/16 [==============================] - 0s 13ms/step - loss: 1.2089e-06 - acc: 1.0000 - val_loss: 2.5063 - val_acc: 0.5750
# Epoch 75/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.1715e-06 - acc: 1.0000 - val_loss: 2.5097 - val_acc: 0.5750
# Epoch 76/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.1563e-06 - acc: 1.0000 - val_loss: 2.5176 - val_acc: 0.5750
# Epoch 77/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.1270e-06 - acc: 1.0000 - val_loss: 2.5215 - val_acc: 0.5750
# Epoch 78/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.0573e-06 - acc: 1.0000 - val_loss: 2.5307 - val_acc: 0.5750
# Epoch 79/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.0271e-06 - acc: 1.0000 - val_loss: 2.5380 - val_acc: 0.5750
# Epoch 80/128
# 16/16 [==============================] - 0s 12ms/step - loss: 1.0059e-06 - acc: 1.0000 - val_loss: 2.5442 - val_acc: 0.5750
# Epoch 81/128
# 16/16 [==============================] - 0s 13ms/step - loss: 9.6436e-07 - acc: 1.0000 - val_loss: 2.5452 - val_acc: 0.5750
# Epoch 82/128
# 16/16 [==============================] - 0s 13ms/step - loss: 9.4013e-07 - acc: 1.0000 - val_loss: 2.5503 - val_acc: 0.5750
# Epoch 83/128
# 16/16 [==============================] - 0s 13ms/step - loss: 9.0445e-07 - acc: 1.0000 - val_loss: 2.5601 - val_acc: 0.5750
# Epoch 84/128
# 16/16 [==============================] - 0s 12ms/step - loss: 8.9720e-07 - acc: 1.0000 - val_loss: 2.5713 - val_acc: 0.5917
# Epoch 85/128
# 16/16 [==============================] - 0s 13ms/step - loss: 8.5201e-07 - acc: 1.0000 - val_loss: 2.5698 - val_acc: 0.5750
# Epoch 86/128
# 16/16 [==============================] - 0s 13ms/step - loss: 8.3328e-07 - acc: 1.0000 - val_loss: 2.5751 - val_acc: 0.5750
# Epoch 87/128
# 16/16 [==============================] - 0s 12ms/step - loss: 8.0551e-07 - acc: 1.0000 - val_loss: 2.5821 - val_acc: 0.5750
# Epoch 88/128
# 16/16 [==============================] - 0s 13ms/step - loss: 7.8378e-07 - acc: 1.0000 - val_loss: 2.5872 - val_acc: 0.5750
# Epoch 89/128
# 16/16 [==============================] - 0s 13ms/step - loss: 7.6450e-07 - acc: 1.0000 - val_loss: 2.5951 - val_acc: 0.5833
# Epoch 90/128
# 16/16 [==============================] - 0s 14ms/step - loss: 7.4417e-07 - acc: 1.0000 - val_loss: 2.5986 - val_acc: 0.5750
# Epoch 91/128
# 16/16 [==============================] - 0s 13ms/step - loss: 7.3389e-07 - acc: 1.0000 - val_loss: 2.6080 - val_acc: 0.5833
# Epoch 92/128
# 16/16 [==============================] - 0s 13ms/step - loss: 7.1263e-07 - acc: 1.0000 - val_loss: 2.6092 - val_acc: 0.5750
# Epoch 93/128
# 16/16 [==============================] - 0s 13ms/step - loss: 6.7713e-07 - acc: 1.0000 - val_loss: 2.6169 - val_acc: 0.5833
# Epoch 94/128
# 16/16 [==============================] - 0s 12ms/step - loss: 6.6603e-07 - acc: 1.0000 - val_loss: 2.6236 - val_acc: 0.5833
# Epoch 95/128
# 16/16 [==============================] - 0s 13ms/step - loss: 6.4626e-07 - acc: 1.0000 - val_loss: 2.6292 - val_acc: 0.5833
# Epoch 96/128
# 16/16 [==============================] - 0s 13ms/step - loss: 6.2674e-07 - acc: 1.0000 - val_loss: 2.6311 - val_acc: 0.5833
# Epoch 97/128
# 16/16 [==============================] - 0s 13ms/step - loss: 6.1116e-07 - acc: 1.0000 - val_loss: 2.6347 - val_acc: 0.5750
# Epoch 98/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.9700e-07 - acc: 1.0000 - val_loss: 2.6423 - val_acc: 0.5833
# Epoch 99/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.8109e-07 - acc: 1.0000 - val_loss: 2.6485 - val_acc: 0.5833
# Epoch 100/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.6964e-07 - acc: 1.0000 - val_loss: 2.6503 - val_acc: 0.5833
# Epoch 101/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.5310e-07 - acc: 1.0000 - val_loss: 2.6577 - val_acc: 0.5917
# Epoch 102/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.4509e-07 - acc: 1.0000 - val_loss: 2.6602 - val_acc: 0.5833
# Epoch 103/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.2863e-07 - acc: 1.0000 - val_loss: 2.6655 - val_acc: 0.5917
# Epoch 104/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.1233e-07 - acc: 1.0000 - val_loss: 2.6702 - val_acc: 0.5917
# Epoch 105/128
# 16/16 [==============================] - 0s 12ms/step - loss: 5.0263e-07 - acc: 1.0000 - val_loss: 2.6737 - val_acc: 0.5833
# Epoch 106/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.9069e-07 - acc: 1.0000 - val_loss: 2.6798 - val_acc: 0.5833
# Epoch 107/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.7766e-07 - acc: 1.0000 - val_loss: 2.6828 - val_acc: 0.5833
# Epoch 108/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.6925e-07 - acc: 1.0000 - val_loss: 2.6895 - val_acc: 0.5833
# Epoch 109/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.5785e-07 - acc: 1.0000 - val_loss: 2.6923 - val_acc: 0.6000
# Epoch 110/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.4763e-07 - acc: 1.0000 - val_loss: 2.6973 - val_acc: 0.6000
# Epoch 111/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.3669e-07 - acc: 1.0000 - val_loss: 2.7013 - val_acc: 0.6000
# Epoch 112/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.2540e-07 - acc: 1.0000 - val_loss: 2.7043 - val_acc: 0.5833
# Epoch 113/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.1635e-07 - acc: 1.0000 - val_loss: 2.7092 - val_acc: 0.5833
# Epoch 114/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.0811e-07 - acc: 1.0000 - val_loss: 2.7154 - val_acc: 0.5917
# Epoch 115/128
# 16/16 [==============================] - 0s 12ms/step - loss: 4.0027e-07 - acc: 1.0000 - val_loss: 2.7189 - val_acc: 0.5917
# Epoch 116/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.9268e-07 - acc: 1.0000 - val_loss: 2.7241 - val_acc: 0.6000
# Epoch 117/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.8353e-07 - acc: 1.0000 - val_loss: 2.7301 - val_acc: 0.6000
# Epoch 118/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.7531e-07 - acc: 1.0000 - val_loss: 2.7297 - val_acc: 0.5833
# Epoch 119/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.6591e-07 - acc: 1.0000 - val_loss: 2.7356 - val_acc: 0.6000
# Epoch 120/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.6192e-07 - acc: 1.0000 - val_loss: 2.7415 - val_acc: 0.6000
# Epoch 121/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.5112e-07 - acc: 1.0000 - val_loss: 2.7421 - val_acc: 0.6000
# Epoch 122/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.4629e-07 - acc: 1.0000 - val_loss: 2.7447 - val_acc: 0.5833
# Epoch 123/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.3510e-07 - acc: 1.0000 - val_loss: 2.7520 - val_acc: 0.6000
# Epoch 124/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.3111e-07 - acc: 1.0000 - val_loss: 2.7585 - val_acc: 0.6000
# Epoch 125/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.2362e-07 - acc: 1.0000 - val_loss: 2.7574 - val_acc: 0.5917
# Epoch 126/128
# 16/16 [==============================] - 0s 12ms/step - loss: 3.1711e-07 - acc: 1.0000 - val_loss: 2.7617 - val_acc: 0.6000
# Epoch 127/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.1495e-07 - acc: 1.0000 - val_loss: 2.7700 - val_acc: 0.6000
# Epoch 128/128
# 16/16 [==============================] - 0s 13ms/step - loss: 3.0385e-07 - acc: 1.0000 - val_loss: 2.7697 - val_acc: 0.5917
# acc:  1.0
# loss:  3.0385106697394804e-07
# val_acc:  0.5916666388511658
# val_loss:  2.7697291374206543
