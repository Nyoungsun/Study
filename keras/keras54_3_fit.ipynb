# %% [markdown]
# # 데이터

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data_Gen = ImageDataGenerator (
    rescale = 1./255, 
    horizontal_flip = True,         # 수평선을 기준으로 반전
    vertical_flip = True,           # 수직선을 기준으로 반전
    width_shift_range = 0.1,        # 10% 만큼 가로 이동
    height_shift_range = 0.1,       # 10% 만큼 세로 이동
    rotation_range = 5,             # 회전
    zoom_range = 0.7,               # 확대
    shear_range = 0.7,              # 엇갈림
    fill_mode = 'nearest'           # 축 이동을 했을 때 비는 부분을 가까운 값으로 채운다.
)

test_data_Gen = ImageDataGenerator (
    rescale = 1./255                # 테스트 데이터는 리스케일링만 한다.: 평가에 쓰이는 테스트 데이터는 증폭시키지 않은 원 데이터 사용
)

xy_train = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/train',
    target_size=(100,100),
    batch_size= 1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True
)

# ad(alzheimer disease) = 0, normal = 1  
# x = (160, 150, 150, 1), y = (160,) → 흑백 image 
# 160장 중에 ad, normal 각 80장씩
# np.unique = 0, 1

xy_test = train_data_Gen.flow_from_directory (
    'C:/study/keras/keras_data/brain/test',
    target_size=(100,100),
    batch_size=1024,                  # 10개씩 자르므로 16번 돈다.
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True
)

# print(xy_train, '\n', xy_test)    # <keras.preprocessing.image.DirectoryIterator object at 0x000002862718CAC0> 
# print(xy_train[0])                # x data와 y data 개수, y data 개수 = batch_size 개수 만큼
# print(xy_train[0][0])
# print(xy_train[0][1])
print(len(xy_train[0]))  
print(xy_train[0][0].shape)         # x (10 = batch_size)
print(xy_train[0][1].shape)         # y

# batch_size를 전체 데이터보다 최대한 크게 끔 지정하면 전체 데이터의 개수를 알 수 있다.
print(type(xy_train)) 
print(type(xy_train[0]))             # 튜플은 변경 불가
print(type(xy_train[0][0]))          # x
print(type(xy_train[0][1]))          # y
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# 2
# (160, 100, 100, 1)
# (160,)
# <class 'keras.preprocessing.image.DirectoryIterator'>
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
#  # 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten

model = Sequential()
model.add(Conv2D(64, (2,2), input_shape=(100, 100, 1), activation='relu'))
model.add(Conv2D(64, (2,2), activation='relu'))
model.add(Conv2D(64, (2,2), activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
#  # 컴파일, 훈련

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics='acc')
# hist = model.fit_generator(xy_train, steps_per_epoch=16, epochs=128, validation_data=xy_test, validation_steps=4)  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수
hist = model.fit(xy_train[0][0], xy_train[0][1], epochs=128, batch_size=10, validation_data=(xy_test[0][0], xy_test[0][1]))  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수

acc = hist.history['acc']
val_acc = hist.history['val_acc']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
print('acc: ', acc[-1])
print('loss: ', loss[-1])
print('val_acc: ', val_acc[-1])
print('val_loss: ', val_loss[-1])
# Out:
# Epoch 1/128
# 16/16 [==============================] - 3s 23ms/step - loss: 0.7361 - acc: 0.5562 - val_loss: 0.6902 - val_acc: 0.5333
# Epoch 2/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6755 - acc: 0.5375 - val_loss: 0.6847 - val_acc: 0.5417
# Epoch 3/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5709 - acc: 0.7125 - val_loss: 0.9152 - val_acc: 0.5000
# Epoch 4/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4242 - acc: 0.7750 - val_loss: 0.6043 - val_acc: 0.6667
# Epoch 5/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2177 - acc: 0.9500 - val_loss: 0.5985 - val_acc: 0.7000
# Epoch 6/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0662 - acc: 0.9937 - val_loss: 0.8364 - val_acc: 0.6583
# Epoch 7/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0191 - acc: 1.0000 - val_loss: 0.7648 - val_acc: 0.7000
# Epoch 8/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 0.6964 - val_acc: 0.6833
# Epoch 9/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.8407 - val_acc: 0.6667
# Epoch 10/128
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 0.8476 - val_acc: 0.6667
# Epoch 11/128
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.8213 - val_acc: 0.7167
# Epoch 12/128
# 16/16 [==============================] - 0s 15ms/step - loss: 7.6451e-04 - acc: 1.0000 - val_loss: 0.8275 - val_acc: 0.6917
# Epoch 13/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.5969e-04 - acc: 1.0000 - val_loss: 0.8347 - val_acc: 0.6833
# Epoch 14/128
# 16/16 [==============================] - 0s 16ms/step - loss: 3.4851e-04 - acc: 1.0000 - val_loss: 0.8528 - val_acc: 0.6750
# Epoch 15/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.8486e-04 - acc: 1.0000 - val_loss: 0.8817 - val_acc: 0.6750
# Epoch 16/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.3837e-04 - acc: 1.0000 - val_loss: 0.8993 - val_acc: 0.7000
# Epoch 17/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.8637e-04 - acc: 1.0000 - val_loss: 0.9273 - val_acc: 0.7000
# Epoch 18/128
# 16/16 [==============================] - 0s 18ms/step - loss: 1.3515e-04 - acc: 1.0000 - val_loss: 0.9603 - val_acc: 0.6833
# Epoch 19/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1266e-04 - acc: 1.0000 - val_loss: 0.9944 - val_acc: 0.7167
# Epoch 20/128
# 16/16 [==============================] - 0s 15ms/step - loss: 8.6332e-05 - acc: 1.0000 - val_loss: 1.0417 - val_acc: 0.6833
# Epoch 21/128
# 16/16 [==============================] - 0s 15ms/step - loss: 6.6555e-05 - acc: 1.0000 - val_loss: 1.0769 - val_acc: 0.6917
# Epoch 22/128
# 16/16 [==============================] - 0s 15ms/step - loss: 5.3761e-05 - acc: 1.0000 - val_loss: 1.0942 - val_acc: 0.7000
# Epoch 23/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.7965e-05 - acc: 1.0000 - val_loss: 1.1103 - val_acc: 0.7083
# Epoch 24/128
# 16/16 [==============================] - 0s 16ms/step - loss: 4.2382e-05 - acc: 1.0000 - val_loss: 1.1377 - val_acc: 0.7000
# Epoch 25/128
# 16/16 [==============================] - 0s 16ms/step - loss: 3.4863e-05 - acc: 1.0000 - val_loss: 1.1536 - val_acc: 0.7000
# Epoch 26/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.8856e-05 - acc: 1.0000 - val_loss: 1.1736 - val_acc: 0.7000
# Epoch 27/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.5070e-05 - acc: 1.0000 - val_loss: 1.1927 - val_acc: 0.7000
# Epoch 28/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.2490e-05 - acc: 1.0000 - val_loss: 1.2115 - val_acc: 0.7000
# Epoch 29/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.1439e-05 - acc: 1.0000 - val_loss: 1.2296 - val_acc: 0.7000
# Epoch 30/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.7649e-05 - acc: 1.0000 - val_loss: 1.2379 - val_acc: 0.7083
# Epoch 31/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.6331e-05 - acc: 1.0000 - val_loss: 1.2388 - val_acc: 0.7083
# Epoch 32/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.4425e-05 - acc: 1.0000 - val_loss: 1.2650 - val_acc: 0.7000
# Epoch 33/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.3165e-05 - acc: 1.0000 - val_loss: 1.2750 - val_acc: 0.7000
# Epoch 34/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2183e-05 - acc: 1.0000 - val_loss: 1.2895 - val_acc: 0.7000
# Epoch 35/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1435e-05 - acc: 1.0000 - val_loss: 1.2937 - val_acc: 0.7000
# Epoch 36/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.0199e-05 - acc: 1.0000 - val_loss: 1.3107 - val_acc: 0.7000
# Epoch 37/128
# 16/16 [==============================] - 0s 15ms/step - loss: 9.5608e-06 - acc: 1.0000 - val_loss: 1.3104 - val_acc: 0.7083
# Epoch 38/128
# 16/16 [==============================] - 0s 15ms/step - loss: 8.8944e-06 - acc: 1.0000 - val_loss: 1.3251 - val_acc: 0.7000
# Epoch 39/128
# 16/16 [==============================] - 0s 15ms/step - loss: 8.0034e-06 - acc: 1.0000 - val_loss: 1.3426 - val_acc: 0.7000
# Epoch 40/128
# 16/16 [==============================] - 0s 15ms/step - loss: 7.6112e-06 - acc: 1.0000 - val_loss: 1.3415 - val_acc: 0.7000
# Epoch 41/128
# 16/16 [==============================] - 0s 15ms/step - loss: 7.1024e-06 - acc: 1.0000 - val_loss: 1.3587 - val_acc: 0.6917
# Epoch 42/128
# 16/16 [==============================] - 0s 15ms/step - loss: 6.6547e-06 - acc: 1.0000 - val_loss: 1.3624 - val_acc: 0.7000
# Epoch 43/128
# 16/16 [==============================] - 0s 15ms/step - loss: 6.1028e-06 - acc: 1.0000 - val_loss: 1.3671 - val_acc: 0.7000
# Epoch 44/128
# 16/16 [==============================] - 0s 15ms/step - loss: 5.7161e-06 - acc: 1.0000 - val_loss: 1.3780 - val_acc: 0.7000
# Epoch 45/128
# 16/16 [==============================] - 0s 15ms/step - loss: 5.7045e-06 - acc: 1.0000 - val_loss: 1.3876 - val_acc: 0.6917
# Epoch 46/128
# 16/16 [==============================] - 0s 15ms/step - loss: 5.3871e-06 - acc: 1.0000 - val_loss: 1.3847 - val_acc: 0.7000
# Epoch 47/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.7383e-06 - acc: 1.0000 - val_loss: 1.4156 - val_acc: 0.6917
# Epoch 48/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.7740e-06 - acc: 1.0000 - val_loss: 1.4228 - val_acc: 0.6917
# Epoch 49/128
# 16/16 [==============================] - 0s 14ms/step - loss: 4.2737e-06 - acc: 1.0000 - val_loss: 1.4059 - val_acc: 0.7000
# Epoch 50/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.1301e-06 - acc: 1.0000 - val_loss: 1.4310 - val_acc: 0.6917
# Epoch 51/128
# 16/16 [==============================] - 0s 15ms/step - loss: 4.0774e-06 - acc: 1.0000 - val_loss: 1.4259 - val_acc: 0.6917
# Epoch 52/128
# 16/16 [==============================] - 0s 15ms/step - loss: 3.6373e-06 - acc: 1.0000 - val_loss: 1.4435 - val_acc: 0.6917
# Epoch 53/128
# 16/16 [==============================] - 0s 15ms/step - loss: 3.5587e-06 - acc: 1.0000 - val_loss: 1.4408 - val_acc: 0.6917
# Epoch 54/128
# 16/16 [==============================] - 0s 16ms/step - loss: 3.3409e-06 - acc: 1.0000 - val_loss: 1.4405 - val_acc: 0.6917
# Epoch 55/128
# 16/16 [==============================] - 0s 15ms/step - loss: 3.1492e-06 - acc: 1.0000 - val_loss: 1.4554 - val_acc: 0.6917
# Epoch 56/128
# 16/16 [==============================] - 0s 15ms/step - loss: 3.0273e-06 - acc: 1.0000 - val_loss: 1.4665 - val_acc: 0.6917
# Epoch 57/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.9176e-06 - acc: 1.0000 - val_loss: 1.4730 - val_acc: 0.6917
# Epoch 58/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.7519e-06 - acc: 1.0000 - val_loss: 1.4611 - val_acc: 0.6917
# Epoch 59/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.6482e-06 - acc: 1.0000 - val_loss: 1.4755 - val_acc: 0.6917
# Epoch 60/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.5523e-06 - acc: 1.0000 - val_loss: 1.4870 - val_acc: 0.6917
# Epoch 61/128
# 16/16 [==============================] - 0s 15ms/step - loss: 2.5786e-06 - acc: 1.0000 - val_loss: 1.4761 - val_acc: 0.6917
# Epoch 62/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.5513e-06 - acc: 1.0000 - val_loss: 1.5131 - val_acc: 0.7000
# Epoch 63/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.3113e-06 - acc: 1.0000 - val_loss: 1.4832 - val_acc: 0.7000
# Epoch 64/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.2107e-06 - acc: 1.0000 - val_loss: 1.5049 - val_acc: 0.6917
# Epoch 65/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.1046e-06 - acc: 1.0000 - val_loss: 1.4991 - val_acc: 0.6917
# Epoch 66/128
# 16/16 [==============================] - 0s 16ms/step - loss: 2.0958e-06 - acc: 1.0000 - val_loss: 1.5237 - val_acc: 0.6917
# Epoch 67/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.9583e-06 - acc: 1.0000 - val_loss: 1.5117 - val_acc: 0.6917
# Epoch 68/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.8373e-06 - acc: 1.0000 - val_loss: 1.5271 - val_acc: 0.6917
# Epoch 69/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.7728e-06 - acc: 1.0000 - val_loss: 1.5224 - val_acc: 0.6917
# Epoch 70/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.6991e-06 - acc: 1.0000 - val_loss: 1.5313 - val_acc: 0.6917
# Epoch 71/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.6628e-06 - acc: 1.0000 - val_loss: 1.5381 - val_acc: 0.6917
# Epoch 72/128
# 16/16 [==============================] - 0s 18ms/step - loss: 1.5968e-06 - acc: 1.0000 - val_loss: 1.5302 - val_acc: 0.6917
# Epoch 73/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.5462e-06 - acc: 1.0000 - val_loss: 1.5448 - val_acc: 0.6917
# Epoch 74/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.4985e-06 - acc: 1.0000 - val_loss: 1.5425 - val_acc: 0.6917
# Epoch 75/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.4411e-06 - acc: 1.0000 - val_loss: 1.5577 - val_acc: 0.6917
# Epoch 76/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.4009e-06 - acc: 1.0000 - val_loss: 1.5551 - val_acc: 0.6917
# Epoch 77/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.3942e-06 - acc: 1.0000 - val_loss: 1.5561 - val_acc: 0.6917
# Epoch 78/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.3414e-06 - acc: 1.0000 - val_loss: 1.5779 - val_acc: 0.6917
# Epoch 79/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2450e-06 - acc: 1.0000 - val_loss: 1.5629 - val_acc: 0.6917
# Epoch 80/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2277e-06 - acc: 1.0000 - val_loss: 1.5663 - val_acc: 0.6917
# Epoch 81/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2246e-06 - acc: 1.0000 - val_loss: 1.5809 - val_acc: 0.6917
# Epoch 82/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.2451e-06 - acc: 1.0000 - val_loss: 1.5646 - val_acc: 0.6917
# Epoch 83/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.1309e-06 - acc: 1.0000 - val_loss: 1.5914 - val_acc: 0.6917
# Epoch 84/128
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1352e-06 - acc: 1.0000 - val_loss: 1.5920 - val_acc: 0.6917
# Epoch 85/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.0896e-06 - acc: 1.0000 - val_loss: 1.5795 - val_acc: 0.6917
# Epoch 86/128
# 16/16 [==============================] - 0s 15ms/step - loss: 1.0192e-06 - acc: 1.0000 - val_loss: 1.5966 - val_acc: 0.6917
# Epoch 87/128
# 16/16 [==============================] - 0s 15ms/step - loss: 9.9756e-07 - acc: 1.0000 - val_loss: 1.6023 - val_acc: 0.6917
# Epoch 88/128
# 16/16 [==============================] - 0s 15ms/step - loss: 9.6283e-07 - acc: 1.0000 - val_loss: 1.6021 - val_acc: 0.6917
# Epoch 89/128
# 16/16 [==============================] - 0s 15ms/step - loss: 9.7591e-07 - acc: 1.0000 - val_loss: 1.5954 - val_acc: 0.6917
# Epoch 90/128
# 16/16 [==============================] - 0s 15ms/step - loss: 9.0624e-07 - acc: 1.0000 - val_loss: 1.6155 - val_acc: 0.6917
# Epoch 91/128
# 16/16 [==============================] - 0s 16ms/step - loss: 9.0528e-07 - acc: 1.0000 - val_loss: 1.6150 - val_acc: 0.6917
# Epoch 92/128
# 16/16 [==============================] - 0s 15ms/step - loss: 8.7205e-07 - acc: 1.0000 - val_loss: 1.6092 - val_acc: 0.6917
# Epoch 93/128
#  1/16 [>.............................] - ETA: 0s - loss: 3.7066e-07 - acc: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1196\1613942248.py in <module>
#       1 model.compile(loss='binary_crossentropy', optimizer='adam', metrics='acc')
#       2 # hist = model.fit_generator(xy_train, steps_per_epoch=16, epochs=128, validation_data=xy_test, validation_steps=4)  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수
# ----> 3 hist = model.fit(xy_train[0][0], xy_train[0][1], epochs=128, batch_size=10, validation_data=(xy_test[0][0], xy_test[0][1]))  # steps_per_epoch: 1 에포크 당 배치 사이즈에 따른 훈련 횟수
#       4
#       5 acc = hist.history['acc']
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:
