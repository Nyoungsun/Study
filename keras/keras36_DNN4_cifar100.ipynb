# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. 데이터

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

print(np.unique(y_train, return_counts = True)) 

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)   

plt.figure(figsize=(20,5))
for i in range(36):
    plt.subplot(4, 9, i+1, xticks=[], yticks=[]) # plt.axis('off')
    plt.imshow(x_train[i], 'gray')        

# ---------- 전처리 (2차원으로 변환) ---------- #
x_train = x_train.reshape(50000, 32*32*3)
x_test = x_test.reshape(10000, 32*32*3)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)  

x_test = x_test/255.0
x_train = x_train/255.0

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22124\1797345274.py in <module>
# ----> 1 (x_train, y_train), (x_test, y_test) = cifar100.load_data()
#       2
#       3 print(np.unique(y_train, return_counts = True))
#       4
#       5 print(x_train.shape, y_train.shape)
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\datasets\cifar100.py in load_data(label_mode)
#      80
#      81   fpath = os.path.join(path, 'train')
# ---> 82   x_train, y_train = load_batch(fpath, label_key=label_mode + '_labels')
#      83
#      84   fpath = os.path.join(path, 'test')
#
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\keras\datasets\cifar.py in load_batch(fpath, label_key)
#      30   """
#      31   with open(fpath, 'rb') as f:
# ---> 32     d = cPickle.load(f, encoding='bytes')
#      33     # decode utf8
#      34     d_decoded = {}
#
# UnpicklingError: pickle data was truncated

# %% [markdown]
# # 2. 모델

# %%
model = Sequential()
model.add(Dense(units=64, input_shape=(32*32*3, ), activation='relu'))
model.add(Dense(units=64, activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(units=32, activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(units=16, activation='relu')) 
model.add(Dense(units=100, activation='softmax')) 
# model.summary()

# %% [markdown]
# # 3. 컴파일 및 훈련

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics='acc') # one-hot encoding 하지 않아도 되는 데이터이므로 loss= sparse_categorical_crossentropy

path = 'C:/study/keras/keras_save/MCP/'
MCP = ModelCheckpoint(monitor='acc', mode='auto', save_best_only=True, filepath=path+'keras36_3_cifar10.hdf5') 
ES = EarlyStopping(monitor='acc', mode='auto', patience=4, restore_best_weights=True) 
model.fit(x_train, y_train, epochs=64, batch_size=512, validation_split=0.2, callbacks=[ES, MCP])
# Out:
# Epoch 1/64
# 79/79 [==============================] - 1s 12ms/step - loss: 4.6061 - acc: 0.0109 - val_loss: 4.5927 - val_acc: 0.0188
# Epoch 2/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.5592 - acc: 0.0188 - val_loss: 4.4642 - val_acc: 0.0278
# Epoch 3/64
# 79/79 [==============================] - 1s 8ms/step - loss: 4.3915 - acc: 0.0296 - val_loss: 4.2900 - val_acc: 0.0389
# Epoch 4/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.2767 - acc: 0.0377 - val_loss: 4.1865 - val_acc: 0.0464
# Epoch 5/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.2063 - acc: 0.0440 - val_loss: 4.1443 - val_acc: 0.0552
# Epoch 6/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.1614 - acc: 0.0514 - val_loss: 4.1041 - val_acc: 0.0580
# Epoch 7/64
# 79/79 [==============================] - 1s 8ms/step - loss: 4.1292 - acc: 0.0549 - val_loss: 4.0717 - val_acc: 0.0660
# Epoch 8/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.0984 - acc: 0.0589 - val_loss: 4.0429 - val_acc: 0.0673
# Epoch 9/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.0696 - acc: 0.0634 - val_loss: 4.0330 - val_acc: 0.0710
# Epoch 10/64
# 79/79 [==============================] - 1s 8ms/step - loss: 4.0418 - acc: 0.0659 - val_loss: 4.0337 - val_acc: 0.0716
# Epoch 11/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.0423 - acc: 0.0649 - val_loss: 4.0185 - val_acc: 0.0734
# Epoch 12/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.0218 - acc: 0.0692 - val_loss: 3.9681 - val_acc: 0.0818
# Epoch 13/64
# 79/79 [==============================] - 1s 7ms/step - loss: 4.0069 - acc: 0.0715 - val_loss: 3.9625 - val_acc: 0.0832
# Epoch 14/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9933 - acc: 0.0745 - val_loss: 3.9493 - val_acc: 0.0857
# Epoch 15/64
# 79/79 [==============================] - 1s 8ms/step - loss: 3.9831 - acc: 0.0762 - val_loss: 3.9356 - val_acc: 0.0901
# Epoch 16/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9701 - acc: 0.0773 - val_loss: 3.9320 - val_acc: 0.0886
# Epoch 17/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9651 - acc: 0.0805 - val_loss: 3.9005 - val_acc: 0.0951
# Epoch 18/64
# 79/79 [==============================] - 1s 8ms/step - loss: 3.9473 - acc: 0.0826 - val_loss: 3.9089 - val_acc: 0.0927
# Epoch 19/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9465 - acc: 0.0815 - val_loss: 3.8929 - val_acc: 0.0933
# Epoch 20/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9293 - acc: 0.0856 - val_loss: 3.9214 - val_acc: 0.0934
# Epoch 21/64
# 79/79 [==============================] - 1s 7ms/step - loss: 3.9215 - acc: 0.0855 - val_loss: 3.8678 - val_acc: 0.0987
# Epoch 22/64
# 21/79 [======>.......................] - ETA: 0s - loss: 3.9025 - acc: 0.0921

# %% [markdown]
# # 4. 평가 및 예측

# %%
metric = model.evaluate(x_test, y_test) # compile에서 metrics = acc를 지정했으므로 evaluate는 값을 배열 형태로 2개 반환함
print('loss: ', metric[0], 'acc: ', metric[1])
