# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("split_dataset.shape :", data.shape)
print("split_pre_data.shape: ", pre_data.shape)

data_x = data[:, :-1] 
data_y = data[:, -1] 

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("data_x.shape: ", data_x.shape, "data_y.shape: ", data_y.shape)

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

x_train = x_train.reshape(-1, 2, 2) # feature = 2로 변경
x_test = x_test.reshape(-1, 2, 2)
pre_data = pre_data.reshape(-1, 2, 2)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# split_dataset.shape : (96, 5)
# split_pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# data_x.shape:  (96, 4) data_y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)
# (67, 2, 2) (67,) (29, 2, 2) (29,)

# %%
model = Sequential()                                                                     
model.add(LSTM(units = 64, input_shape=(2, 2), return_sequences=True, activation='relu')) 
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2, 64)             17152
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 58,561
# Trainable params: 58,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 1s 2ms/step - loss: 2155.5222
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 92.7722
# Epoch 3/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2421
# Epoch 4/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5878
# Epoch 5/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.9198
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3267
# Epoch 7/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2565
# Epoch 8/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2058
# Epoch 9/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1681
# Epoch 10/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1389
# Epoch 11/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1448
# Epoch 12/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1149
# Epoch 13/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0985
# Epoch 14/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0844
# Epoch 15/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 16/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0616
# Epoch 17/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0500
# Epoch 18/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0410
# Epoch 19/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0364
# Epoch 20/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0355
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0370
# Epoch 22/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0261
# Epoch 23/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0185
# Epoch 24/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 25/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 26/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 27/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0115
# Epoch 28/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 29/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0113
# Epoch 30/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0120
# Epoch 31/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 32/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 33/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 34/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 35/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 36/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 37/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 38/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 39/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 40/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 41/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 42/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 43/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 44/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 45/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 46/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 47/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 48/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 49/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 50/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.5106e-04
# Epoch 51/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.5950e-04
# Epoch 52/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.7602e-04
# Epoch 53/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0958e-04
# Epoch 54/128
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 55/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 56/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.3261e-04
# Epoch 57/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5843e-04
# Epoch 58/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1198e-04
# Epoch 59/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7318e-04
# Epoch 60/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2741e-04
# Epoch 61/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 62/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 63/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 64/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8966e-04
# Epoch 65/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1006e-04
# Epoch 66/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7012e-04
# Epoch 67/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1742e-04
# Epoch 68/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9424e-04
# Epoch 69/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9671e-04
# Epoch 70/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4755e-04
# Epoch 71/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7872e-05
# Epoch 72/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.0371e-05
# Epoch 73/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3552e-04
# Epoch 74/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1394e-04
# Epoch 75/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.5019e-05
# Epoch 76/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0165e-05
# Epoch 77/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.6508e-05
# Epoch 78/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5950e-05
# Epoch 79/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6452e-05
# Epoch 80/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8033e-05
# Epoch 81/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7143e-05
# Epoch 82/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0238e-05
# Epoch 83/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6518e-05
# Epoch 84/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8113e-05
# Epoch 85/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4163e-04
# Epoch 86/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.8115e-04
# Epoch 87/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2450e-04
# Epoch 88/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6973e-04
# Epoch 89/128
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7537e-04
# Epoch 90/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 91/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 92/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7531e-04
# Epoch 93/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 94/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 95/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.3322e-04
# Epoch 96/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.5908e-05
# Epoch 97/128
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4757e-05
# Epoch 98/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2542e-04
# Epoch 99/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1061e-04
# Epoch 100/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3825e-04
# Epoch 101/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6947e-04
# Epoch 102/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3001e-04
# Epoch 103/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.1787e-04
# Epoch 104/128
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5148e-04
# Epoch 105/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5331e-04
# Epoch 106/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.8137e-04
# Epoch 107/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4920e-04
# Epoch 108/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4281e-04
# Epoch 109/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1691e-04
# Epoch 110/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3176e-04
# Epoch 111/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1832e-04
# Epoch 112/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.2117e-05
# Epoch 113/128
# 23/23 [==============================] - 0s 3ms/step - loss: 1.9880e-05
# Epoch 114/128
# 23/23 [==============================] - 0s 3ms/step - loss: 9.4185e-05
# Epoch 115/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0079e-04
# Epoch 116/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6238e-05
# Epoch 117/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.5377e-04
# Epoch 118/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 119/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0404
# Epoch 120/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2516
# Epoch 121/128
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3188
# Epoch 122/128
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7263
# Epoch 123/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6250
# Epoch 124/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6422
# Epoch 125/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3865
# Epoch 126/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0326
# Epoch 127/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 128/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0052

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0517
# 0.05174696817994118
# prediction result:
#  [[ 99.9636  ]
#  [100.96311 ]
#  [101.962715]
#  [102.962395]
#  [103.96218 ]
#  [104.96206 ]]
