# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("split_dataset.shape :", data.shape)
print("split_pre_data.shape: ", pre_data.shape)

data_x = data[:, :-1] 
data_y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("data_x.shape: ", data_x.shape, "data_y.shape: ", data_y.shape)

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

x_train = x_train.reshape(-1, 2, 2) # feature = 2로 변경
x_test = x_test.reshape(-1, 2, 2)
pre_data = pre_data.reshape(-1, 2, 2)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# split_dataset.shape : (96, 5)
# split_pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# slicing_x.shape:  (96, 4) slicing_y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)
# (67, 2, 2) (67,) (29, 2, 2) (29,)

# %%
model = Sequential()                                                                     
model.add(LSTM(units = 64, input_shape=(2, 2), return_sequences=True, activation='relu')) 
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 2, 64)             17152
#
#  lstm_8 (LSTM)               (None, 64)                33024
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 58,561
# Trainable params: 58,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 1s 3ms/step - loss: 1758.5417
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 101.3116
# Epoch 3/128
# 23/23 [==============================] - 0s 2ms/step - loss: 10.5633
# Epoch 4/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2360
# Epoch 5/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8445
# Epoch 6/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5469
# Epoch 7/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4725
# Epoch 8/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3419
# Epoch 9/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2646
# Epoch 10/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2682
# Epoch 11/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1894
# Epoch 12/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1444
# Epoch 13/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1103
# Epoch 14/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0916
# Epoch 15/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0797
# Epoch 16/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0622
# Epoch 17/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 18/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0628
# Epoch 19/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 20/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0353
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 22/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 23/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 24/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 25/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0203
# Epoch 26/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 27/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 28/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 29/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 30/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 31/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 32/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 33/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 34/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 35/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 36/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 37/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 38/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 39/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 40/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 41/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 42/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 43/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 44/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 45/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 46/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 47/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 48/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 49/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 50/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 51/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 52/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 53/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 54/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 55/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 56/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 57/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 58/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0320
# Epoch 59/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 60/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 61/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 62/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 63/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 64/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 65/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 66/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 67/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 68/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 69/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 70/128
# 23/23 [==============================] - 0s 2ms/step - loss: 7.7308e-04
# Epoch 71/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 72/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 73/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 74/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 75/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 76/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 77/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 78/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 79/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 80/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 81/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 82/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 83/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 84/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.7454e-04
# Epoch 85/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 86/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 87/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 88/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 89/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 90/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 91/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0403
# Epoch 92/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1144
# Epoch 93/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4296
# Epoch 94/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1961
# Epoch 95/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2519
# Epoch 96/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1104
# Epoch 97/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0173
# Epoch 98/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 99/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 100/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 101/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 102/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 103/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 104/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 105/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 106/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 107/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 108/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 109/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 110/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 111/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 112/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 113/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 114/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 115/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 116/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 117/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 118/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 119/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 120/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 121/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 122/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 123/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 124/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 125/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0801
# Epoch 126/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 127/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0353
# Epoch 128/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1220

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

y_predict = np.array(pre_data)

result = model.predict(y_predict)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0505
# 0.05051634460687637
# prediction result:
#  [[100.03429 ]
#  [101.05027 ]
#  [102.06682 ]
#  [103.08394 ]
#  [104.10163 ]
#  [105.119896]]
