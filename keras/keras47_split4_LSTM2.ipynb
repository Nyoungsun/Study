# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("split_dataset.shape :", data.shape)
print("split_pre_data.shape: ", pre_data.shape)

data_x = data[:, :-1] 
data_y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("data_x.shape: ", data_x.shape, "data_y.shape: ", data_y.shape)

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

x_train = x_train.reshape(-1, 2, 2) # feature = 2로 변경
x_test = x_test.reshape(-1, 2, 2)
pre_data = pre_data.reshape(-1, 2, 2)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# split_dataset.shape : (96, 5)
# split_pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# data_x.shape:  (96, 4) data_y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)
# (67, 2, 2) (67,) (29, 2, 2) (29,)

# %%
model = Sequential()                                                                     
model.add(LSTM(units = 64, input_shape=(2, 2), return_sequences=True, activation='relu')) 
model.add(LSTM(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 2, 64)             17152
#
#  lstm_12 (LSTM)              (None, 64)                33024
#
#  dense_15 (Dense)            (None, 64)                4160
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 58,561
# Trainable params: 58,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 2s 3ms/step - loss: 1957.6624
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 243.6536
# Epoch 3/128
# 23/23 [==============================] - 0s 2ms/step - loss: 10.9648
# Epoch 4/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.2389
# Epoch 5/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4667
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3153
# Epoch 7/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2426
# Epoch 8/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2101
# Epoch 9/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1365
# Epoch 10/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1180
# Epoch 11/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0894
# Epoch 12/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 13/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0624
# Epoch 14/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0508
# Epoch 15/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0472
# Epoch 16/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 17/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 18/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0223
# Epoch 19/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 20/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 21/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 22/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 23/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 24/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 25/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0107
# Epoch 26/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 27/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 28/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 29/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 30/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 31/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 32/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 33/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 34/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 35/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 36/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 37/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 38/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 39/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 40/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 41/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 42/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 43/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 44/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 45/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 46/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 47/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 48/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 49/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 50/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 51/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.8597e-04
# Epoch 52/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 53/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 54/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 55/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 56/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 57/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 58/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 59/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 60/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 61/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 62/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.2555e-04
# Epoch 63/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 64/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 65/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 66/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 67/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 68/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 69/128
# 23/23 [==============================] - 0s 2ms/step - loss: 9.7484e-04
# Epoch 70/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 71/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 72/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.9662e-04
# Epoch 73/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 74/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 75/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 76/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 77/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 78/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 79/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 80/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 81/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 82/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 83/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 84/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 85/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 86/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.4995e-04
# Epoch 87/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.3676e-04
# Epoch 88/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 89/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 90/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 91/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 92/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 93/128
# 23/23 [==============================] - 0s 2ms/step - loss: 9.4388e-04
# Epoch 94/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.2877e-04
# Epoch 95/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.0600e-04
# Epoch 96/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 97/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 98/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 99/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 100/128
# 23/23 [==============================] - 0s 2ms/step - loss: 9.6999e-04
# Epoch 101/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 102/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 103/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 104/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 105/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 106/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 107/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 108/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6886e-04
# Epoch 109/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 110/128
# 23/23 [==============================] - 0s 3ms/step - loss: 8.9907e-04
# Epoch 111/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 112/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 113/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 114/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 115/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 116/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 117/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 118/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3179
# Epoch 119/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4975
# Epoch 120/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7135
# Epoch 121/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9512
# Epoch 122/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8056
# Epoch 123/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1318
# Epoch 124/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 125/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 126/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1113
# Epoch 127/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0439
# Epoch 128/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0094

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 198ms/step - loss: 0.0341
# 0.03405814245343208
# prediction result:
#  [[100.05774 ]
#  [101.05515 ]
#  [102.05231 ]
#  [103.049286]
#  [104.046036]
#  [105.04262 ]]
