# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv2D, Flatten
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("split_dataset.shape :", data.shape)
print("split_pre_data.shape: ", pre_data.shape)

data_x = data[:, :-1] 
data_y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("data_x.shape: ", data_x.shape, "data_y.shape: ", data_y.shape)

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

x_train = x_train.reshape(-1, 4, 1, 1)
x_test = x_test.reshape(-1, 4, 1, 1)
pre_data = pre_data.reshape(-1, 4, 1, 1)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# split_dataset.shape : (96, 5)
# split_pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# data_x.shape:  (96, 4) data_y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)
# (67, 4, 1, 1) (67,) (29, 4, 1, 1) (29,)

# %%
model = Sequential()                                                                     
model.add(Conv2D(filters = 64, kernel_size= (2, 1), input_shape=(4, 1, 1), activation='relu')) 
model.add(Conv2D(filters = 64, kernel_size= (2, 1), activation = 'relu'))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 3, 1, 64)          192
#
#  conv2d_2 (Conv2D)           (None, 2, 1, 64)          8256
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 20,929
# Trainable params: 20,929
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 4s 13ms/step - loss: 861.7538
# Epoch 2/128
# 23/23 [==============================] - 0s 4ms/step - loss: 23.0964
# Epoch 3/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.8220
# Epoch 4/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.9921
# Epoch 5/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8416
# Epoch 6/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7972
# Epoch 7/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8016
# Epoch 8/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7792
# Epoch 9/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7054
# Epoch 10/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7366
# Epoch 11/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6634
# Epoch 12/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6406
# Epoch 13/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5196
# Epoch 14/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5285
# Epoch 15/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5055
# Epoch 16/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4725
# Epoch 17/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5055
# Epoch 18/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4362
# Epoch 19/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2951
# Epoch 20/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5066
# Epoch 21/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4196
# Epoch 22/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1533
# Epoch 23/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1028
# Epoch 24/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1570
# Epoch 25/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0799
# Epoch 26/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0418
# Epoch 27/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0371
# Epoch 28/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0193
# Epoch 29/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0115
# Epoch 30/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071
# Epoch 31/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 32/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 33/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 34/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 35/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 36/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 37/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 38/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 39/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 40/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.6717e-04
# Epoch 41/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.8754e-04
# Epoch 42/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.4514e-05
# Epoch 43/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.0204e-05
# Epoch 44/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.0068e-05
# Epoch 45/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.6256e-05
# Epoch 46/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.2899e-05
# Epoch 47/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3556e-05
# Epoch 48/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3197e-05
# Epoch 49/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2292e-05
# Epoch 50/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3129e-05
# Epoch 51/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.8460e-05
# Epoch 52/128
# 23/23 [==============================] - 0s 5ms/step - loss: 1.2025e-05
# Epoch 53/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.6304e-05
# Epoch 54/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2877e-05
# Epoch 55/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2376e-05
# Epoch 56/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1470e-05
# Epoch 57/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3362e-05
# Epoch 58/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1365e-05
# Epoch 59/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1450e-05
# Epoch 60/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2489e-05
# Epoch 61/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0783e-05
# Epoch 62/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2535e-05
# Epoch 63/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4919e-05
# Epoch 64/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.5038e-04
# Epoch 65/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.8419e-04
# Epoch 66/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 67/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 68/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 69/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0117
# Epoch 70/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 71/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 72/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 73/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.4452e-05
# Epoch 74/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3267e-05
# Epoch 75/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2025e-05
# Epoch 76/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.6828e-05
# Epoch 77/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0449e-05
# Epoch 78/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.8234e-05
# Epoch 79/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0933e-05
# Epoch 80/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.3115e-06
# Epoch 81/128
# 23/23 [==============================] - 0s 4ms/step - loss: 8.9009e-06
# Epoch 82/128
# 23/23 [==============================] - 0s 4ms/step - loss: 8.8769e-06
# Epoch 83/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.8865e-05
# Epoch 84/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1978e-04
# Epoch 85/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4698e-04
# Epoch 86/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3098e-04
# Epoch 87/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.8056e-05
# Epoch 88/128
# 23/23 [==============================] - 0s 4ms/step - loss: 8.4186e-06
# Epoch 89/128
# 23/23 [==============================] - 0s 4ms/step - loss: 7.9673e-06
# Epoch 90/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4581e-05
# Epoch 91/128
# 23/23 [==============================] - 0s 4ms/step - loss: 8.8187e-05
# Epoch 92/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1592e-05
# Epoch 93/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0228e-05
# Epoch 94/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.4856e-05
# Epoch 95/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.9088e-05
# Epoch 96/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.1661e-05
# Epoch 97/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.5058e-04
# Epoch 98/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 99/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0198
# Epoch 100/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0498
# Epoch 101/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.8546e-04
# Epoch 102/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.7710e-04
# Epoch 103/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 104/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0317
# Epoch 105/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3792
# Epoch 106/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5865
# Epoch 107/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2164
# Epoch 108/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0138
# Epoch 109/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 110/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.7829e-04
# Epoch 111/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.9990e-04
# Epoch 112/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.0067e-04
# Epoch 113/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3493e-04
# Epoch 114/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1934e-04
# Epoch 115/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 116/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 117/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0108
# Epoch 118/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0309
# Epoch 119/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0093
# Epoch 120/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0101
# Epoch 121/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0321
# Epoch 122/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0387
# Epoch 123/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0086
# Epoch 124/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1515
# Epoch 125/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3216
# Epoch 126/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4481
# Epoch 127/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.5879
# Epoch 128/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.6724

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

y_predict = np.array(pre_data)

result = model.predict(y_predict)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 166ms/step - loss: 0.7841
# 0.7840694785118103
# prediction result:
#  [[101.533394]
#  [102.551155]
#  [103.568924]
#  [104.586685]
#  [105.604454]
#  [106.62221 ]]
