# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv2D, Flatten
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("split_dataset.shape :", data.shape)
print("split_pre_data.shape: ", pre_data.shape)

data_x = data[:, :-1] 
data_y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("data_x.shape: ", data_x.shape, "data_y.shape: ", data_y.shape)

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

x_train = x_train.reshape(-1, 4, 1, 1)
x_test = x_test.reshape(-1, 4, 1, 1)
pre_data = pre_data.reshape(-1, 4, 1, 1)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# split_dataset.shape : (96, 5)
# split_pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# data_x.shape:  (96, 4) data_y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)
# (67, 4, 1, 1) (67,) (29, 4, 1, 1) (29,)

# %%
model = Sequential()                                                                     
model.add(Conv2D(filters = 64, kernel_size= (2, 1), input_shape=(4, 1, 1), activation='relu')) 
model.add(Conv2D(filters = 64, kernel_size= (2, 1), activation = 'relu'))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 3, 1, 64)          192
#
#  conv2d_8 (Conv2D)           (None, 2, 1, 64)          8256
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 20,929
# Trainable params: 20,929
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 0s 6ms/step - loss: 1054.2891
# Epoch 2/128
# 23/23 [==============================] - 0s 5ms/step - loss: 48.2144
# Epoch 3/128
# 23/23 [==============================] - 0s 4ms/step - loss: 7.2127
# Epoch 4/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1647
# Epoch 5/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1350
# Epoch 6/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.9090
# Epoch 7/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7469
# Epoch 8/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7074
# Epoch 9/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7107
# Epoch 10/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6080
# Epoch 11/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6003
# Epoch 12/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7653
# Epoch 13/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5796
# Epoch 14/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4700
# Epoch 15/128
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4093
# Epoch 16/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3375
# Epoch 17/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3278
# Epoch 18/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2884
# Epoch 19/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2610
# Epoch 20/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1880
# Epoch 21/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1624
# Epoch 22/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1505
# Epoch 23/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2386
# Epoch 24/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0963
# Epoch 25/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0650
# Epoch 26/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0720
# Epoch 27/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0657
# Epoch 28/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1153
# Epoch 29/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0372
# Epoch 30/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0158
# Epoch 31/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100
# Epoch 32/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0112
# Epoch 33/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098
# Epoch 34/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087
# Epoch 35/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 36/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 37/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.2831e-04
# Epoch 38/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3212e-04
# Epoch 39/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0181e-04
# Epoch 40/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.8498e-05
# Epoch 41/128
# 23/23 [==============================] - 0s 5ms/step - loss: 3.7516e-05
# Epoch 42/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2264e-05
# Epoch 43/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.9847e-06
# Epoch 44/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.2888e-06
# Epoch 45/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.2420e-06
# Epoch 46/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.8716e-06
# Epoch 47/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7217e-06
# Epoch 48/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.9019e-06
# Epoch 49/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.3137e-06
# Epoch 50/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7445e-06
# Epoch 51/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.8064e-06
# Epoch 52/128
# 23/23 [==============================] - 0s 5ms/step - loss: 4.8730e-06
# Epoch 53/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.1586e-06
# Epoch 54/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.9106e-06
# Epoch 55/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.6629e-06
# Epoch 56/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.0481e-06
# Epoch 57/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.9987e-06
# Epoch 58/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2180e-05
# Epoch 59/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.6068e-06
# Epoch 60/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7589e-06
# Epoch 61/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.2618e-06
# Epoch 62/128
# 23/23 [==============================] - 0s 4ms/step - loss: 7.5643e-06
# Epoch 63/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.8571e-06
# Epoch 64/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.1907e-06
# Epoch 65/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.5425e-06
# Epoch 66/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7462e-06
# Epoch 67/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7915e-06
# Epoch 68/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.6284e-06
# Epoch 69/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.5357e-06
# Epoch 70/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7927e-06
# Epoch 71/128
# 23/23 [==============================] - 0s 4ms/step - loss: 7.1576e-06
# Epoch 72/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.7623e-06
# Epoch 73/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.2097e-06
# Epoch 74/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.8796e-06
# Epoch 75/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.2474e-06
# Epoch 76/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.7758e-06
# Epoch 77/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.9725e-06
# Epoch 78/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.7928e-06
# Epoch 79/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.9098e-06
# Epoch 80/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7651e-06
# Epoch 81/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.6690e-05
# Epoch 82/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4219e-04
# Epoch 83/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.7791e-05
# Epoch 84/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.0572e-05
# Epoch 85/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.8489e-05
# Epoch 86/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.1435e-05
# Epoch 87/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.8395e-05
# Epoch 88/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.5218e-05
# Epoch 89/128
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 90/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 91/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0145
# Epoch 92/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0622
# Epoch 93/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2232
# Epoch 94/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0486
# Epoch 95/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0154
# Epoch 96/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 97/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3619e-04
# Epoch 98/128
# 23/23 [==============================] - 0s 4ms/step - loss: 5.4045e-04
# Epoch 99/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 100/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 101/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0414
# Epoch 102/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0135
# Epoch 103/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 104/128
# 23/23 [==============================] - 0s 4ms/step - loss: 7.7605e-04
# Epoch 105/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0168
# Epoch 106/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0127
# Epoch 107/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 108/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 109/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 110/128
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0164
# Epoch 111/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.9378e-04
# Epoch 112/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3274e-04
# Epoch 113/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.5175e-04
# Epoch 114/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.5937e-04
# Epoch 115/128
# 23/23 [==============================] - 0s 5ms/step - loss: 1.7290e-04
# Epoch 116/128
# 23/23 [==============================] - 0s 4ms/step - loss: 6.1961e-05
# Epoch 117/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.6066e-05
# Epoch 118/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3625e-04
# Epoch 119/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.2305e-05
# Epoch 120/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3221e-05
# Epoch 121/128
# 23/23 [==============================] - 0s 4ms/step - loss: 3.8672e-04
# Epoch 122/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.8621e-05
# Epoch 123/128
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0470e-05
# Epoch 124/128
# 23/23 [==============================] - 0s 4ms/step - loss: 4.7371e-06
# Epoch 125/128
# 23/23 [==============================] - 0s 5ms/step - loss: 1.8313e-05
# Epoch 126/128
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3386e-05
# Epoch 127/128
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0585e-05
# Epoch 128/128
# 23/23 [==============================] - 0s 4ms/step - loss: 9.6060e-06

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 79ms/step - loss: 7.8888e-05
# 7.888847903814167e-05
# prediction result:
#  [[100.004585]
#  [101.004616]
#  [102.00465 ]
#  [103.00469 ]
#  [104.00472 ]
#  [105.00476 ]]
