# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Activation
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", data.shape)
print("pre_data.shape: ", pre_data.shape)

x = data[:, :-1] 
y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# x_train = x_train.reshape(-1, 4, 1)
# x_test = x_test.reshape(-1, 4, 1)
# pre_data = pre_data.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# x.shape:  (96, 4) y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)

# %% [markdown]
# # 모델

# %%
model = Sequential()                                                                     
model.add(Bidirectional(LSTM(64, activation='relu'), input_shape=(4, 1)))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 
# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 128)              33792
#  l)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 46,273
# Trainable params: 46,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 1s 3ms/step - loss: 1539.2805
# Epoch 2/128
# 23/23 [==============================] - 0s 3ms/step - loss: 72.3203
# Epoch 3/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.5298
# Epoch 4/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.9094
# Epoch 5/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3591
# Epoch 6/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1794
# Epoch 7/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1075
# Epoch 8/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0645
# Epoch 9/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 10/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0229
# Epoch 11/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 12/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 13/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 14/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 15/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 16/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 17/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 18/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 19/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 20/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 21/128
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 22/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 23/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 24/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 25/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 26/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 27/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 28/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 29/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 30/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 31/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 32/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 33/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 34/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 35/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 36/128
# 23/23 [==============================] - 0s 2ms/step - loss: 9.7030e-04
# Epoch 37/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 38/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 39/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 40/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 41/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 42/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 43/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 44/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 45/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 46/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 47/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 48/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 49/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 50/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 51/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 52/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 53/128
# 23/23 [==============================] - 0s 2ms/step - loss: 9.2702e-04
# Epoch 54/128
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0201e-04
# Epoch 55/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 56/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.6538e-04
# Epoch 57/128
# 23/23 [==============================] - 0s 2ms/step - loss: 7.6852e-04
# Epoch 58/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9268e-04
# Epoch 59/128
# 23/23 [==============================] - 0s 2ms/step - loss: 7.6731e-04
# Epoch 60/128
# 23/23 [==============================] - 0s 2ms/step - loss: 7.9542e-04
# Epoch 61/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1799e-04
# Epoch 62/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9728e-04
# Epoch 63/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4635e-04
# Epoch 64/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0702e-04
# Epoch 65/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.5670e-04
# Epoch 66/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.3979e-04
# Epoch 67/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.8635e-04
# Epoch 68/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.0099e-04
# Epoch 69/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5037e-04
# Epoch 70/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1749e-04
# Epoch 71/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7599e-04
# Epoch 72/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.9379e-04
# Epoch 73/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.4847e-04
# Epoch 74/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.7401e-04
# Epoch 75/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7751e-04
# Epoch 76/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2120e-04
# Epoch 77/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7131e-04
# Epoch 78/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4759e-04
# Epoch 79/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.0477e-04
# Epoch 80/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.3831e-04
# Epoch 81/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8239e-04
# Epoch 82/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.2305e-04
# Epoch 83/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.9780e-04
# Epoch 84/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.6788e-05
# Epoch 85/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.6005e-04
# Epoch 86/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1954e-04
# Epoch 87/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1269e-04
# Epoch 88/128
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8071e-04
# Epoch 89/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.0772e-04
# Epoch 90/128
# 23/23 [==============================] - 0s 2ms/step - loss: 3.2272e-04
# Epoch 91/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.2321e-04
# Epoch 92/128
# 23/23 [==============================] - 0s 2ms/step - loss: 2.7383e-04
# Epoch 93/128
# 23/23 [==============================] - 0s 2ms/step - loss: 7.1883e-04
# Epoch 94/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.8259e-04
# Epoch 95/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.4112e-04
# Epoch 96/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 97/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 98/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 99/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.0769e-04
# Epoch 100/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 101/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 102/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 103/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 104/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 105/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 106/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 107/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.9635e-04
# Epoch 108/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.6590e-04
# Epoch 109/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 110/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.6213e-04
# Epoch 111/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 112/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.5490e-04
# Epoch 113/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.3056e-04
# Epoch 114/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.2083e-04
# Epoch 115/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 116/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 117/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 118/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 119/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 120/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 121/128
# 23/23 [==============================] - 0s 2ms/step - loss: 6.4425e-04
# Epoch 122/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 123/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 124/128
# 23/23 [==============================] - 0s 2ms/step - loss: 8.4392e-04
# Epoch 125/128
# 23/23 [==============================] - 0s 2ms/step - loss: 4.5770e-04
# Epoch 126/128
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6538e-04
# Epoch 127/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 128/128
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0132

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print(loss)

result = model.predict(pre_data)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0979
# 0.09789765626192093
# prediction result:
#  [[ 99.616714]
#  [100.61232 ]
#  [101.60771 ]
#  [102.602905]
#  [103.597885]
#  [104.59269 ]]
