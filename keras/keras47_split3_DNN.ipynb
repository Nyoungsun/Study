# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터

# %%
data = np.array(range(1, 101)) 
pre_data = np.array(range(96, 106))  
timesteps = 5

def split_x(dataset, timesteps):
    tmp = []
    for i in range(len(dataset) - timesteps + 1):  
        subset = dataset[i : (i + timesteps)]
        tmp.append(subset)
    return np.array(tmp)

data = split_x(data, timesteps) 
pre_data = split_x(pre_data, timesteps)

print("dataset.shape :", data.shape)
print("pre_data.shape: ", pre_data.shape)

x = data[:, :-1] 
y = data[:, -1]

pre_data = pre_data[:, :-1] 
print("slicing_pre_data.shape : ", pre_data.shape)
print("slicing_pre_data:\n", pre_data)

print("x.shape: ", x.shape, "y.shape: ", y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=3333) # default train_size = 0.75

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# x_train = x_train.reshape(-1, 4, 1)
# x_test = x_test.reshape(-1, 4, 1)
# pre_data = pre_data.reshape(-1, 4, 1)
# Out:
# dataset.shape : (96, 5)
# pre_data.shape:  (6, 5)
# slicing_pre_data.shape :  (6, 4)
# slicing_pre_data:
#  [[ 96  97  98  99]
#  [ 97  98  99 100]
#  [ 98  99 100 101]
#  [ 99 100 101 102]
#  [100 101 102 103]
#  [101 102 103 104]]
# x.shape:  (96, 4) y.shape:  (96,)
# (67, 4) (67,) (29, 4) (29,)

# %%
model = Sequential()                                                                     
model.add(Dense(units = 64, input_shape=(4,), activation='relu')) 
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64))
model.add(Dense(1))
model.summary() 

# LSTM을 두 개의 layer에서 사용할 때에는 return_sequences 파라미터를 지정해야한다. (default = False)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 64)                320
#
#  dense_21 (Dense)            (None, 64)                4160
#
#  dense_22 (Dense)            (None, 64)                4160
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dense_24 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12,865
# Trainable params: 12,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 컴파일, 훈련

# %%
model.compile(loss='mse', optimizer= 'adam')
model.fit(x_train, y_train, epochs=128, batch_size=3)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 0s 1ms/step - loss: 4.1150
# Epoch 2/128
# 23/23 [==============================] - 0s 954us/step - loss: 1.6891
# Epoch 3/128
# 23/23 [==============================] - 0s 999us/step - loss: 0.9703
# Epoch 4/128
# 23/23 [==============================] - 0s 956us/step - loss: 0.1170
# Epoch 5/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 6/128
# 23/23 [==============================] - 0s 1ms/step - loss: 1.4019e-04
# Epoch 7/128
# 23/23 [==============================] - 0s 953us/step - loss: 4.9061e-05
# Epoch 8/128
# 23/23 [==============================] - 0s 1ms/step - loss: 6.2766e-05
# Epoch 9/128
# 23/23 [==============================] - 0s 1000us/step - loss: 6.1052e-05
# Epoch 10/128
# 23/23 [==============================] - 0s 1000us/step - loss: 3.2349e-05
# Epoch 11/128
# 23/23 [==============================] - 0s 955us/step - loss: 6.0650e-05
# Epoch 12/128
# 23/23 [==============================] - 0s 1ms/step - loss: 3.1939e-05
# Epoch 13/128
# 23/23 [==============================] - 0s 955us/step - loss: 2.8921e-05
# Epoch 14/128
# 23/23 [==============================] - 0s 954us/step - loss: 3.9959e-05
# Epoch 15/128
# 23/23 [==============================] - 0s 953us/step - loss: 3.9513e-05
# Epoch 16/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.6748e-05
# Epoch 17/128
# 23/23 [==============================] - 0s 1ms/step - loss: 3.9976e-05
# Epoch 18/128
# 23/23 [==============================] - 0s 999us/step - loss: 1.5811e-05
# Epoch 19/128
# 23/23 [==============================] - 0s 1ms/step - loss: 1.6814e-05
# Epoch 20/128
# 23/23 [==============================] - 0s 1ms/step - loss: 1.2599e-05
# Epoch 21/128
# 23/23 [==============================] - 0s 956us/step - loss: 1.1524e-05
# Epoch 22/128
# 23/23 [==============================] - 0s 1ms/step - loss: 1.7201e-05
# Epoch 23/128
# 23/23 [==============================] - 0s 864us/step - loss: 7.5269e-06
# Epoch 24/128
# 23/23 [==============================] - 0s 955us/step - loss: 1.0362e-05
# Epoch 25/128
# 23/23 [==============================] - 0s 910us/step - loss: 5.1284e-06
# Epoch 26/128
# 23/23 [==============================] - 0s 864us/step - loss: 1.4432e-05
# Epoch 27/128
# 23/23 [==============================] - 0s 909us/step - loss: 3.3510e-06
# Epoch 28/128
# 23/23 [==============================] - 0s 955us/step - loss: 5.6130e-06
# Epoch 29/128
# 23/23 [==============================] - 0s 910us/step - loss: 2.8769e-06
# Epoch 30/128
# 23/23 [==============================] - 0s 999us/step - loss: 9.3781e-06
# Epoch 31/128
# 23/23 [==============================] - 0s 910us/step - loss: 1.1169e-05
# Epoch 32/128
# 23/23 [==============================] - 0s 865us/step - loss: 7.1196e-06
# Epoch 33/128
# 23/23 [==============================] - 0s 909us/step - loss: 3.2139e-06
# Epoch 34/128
# 23/23 [==============================] - 0s 910us/step - loss: 3.8627e-06
# Epoch 35/128
# 23/23 [==============================] - 0s 863us/step - loss: 5.8694e-06
# Epoch 36/128
# 23/23 [==============================] - 0s 955us/step - loss: 2.9278e-06
# Epoch 37/128
# 23/23 [==============================] - 0s 862us/step - loss: 1.2680e-06
# Epoch 38/128
# 23/23 [==============================] - 0s 955us/step - loss: 2.9205e-06
# Epoch 39/128
# 23/23 [==============================] - 0s 908us/step - loss: 2.0714e-05
# Epoch 40/128
# 23/23 [==============================] - 0s 909us/step - loss: 9.1716e-05
# Epoch 41/128
# 23/23 [==============================] - 0s 908us/step - loss: 0.0014
# Epoch 42/128
# 23/23 [==============================] - 0s 908us/step - loss: 0.0259
# Epoch 43/128
# 23/23 [==============================] - 0s 954us/step - loss: 0.0015
# Epoch 44/128
# 23/23 [==============================] - 0s 865us/step - loss: 2.9148e-05
# Epoch 45/128
# 23/23 [==============================] - 0s 908us/step - loss: 1.4945e-05
# Epoch 46/128
# 23/23 [==============================] - 0s 910us/step - loss: 3.3224e-05
# Epoch 47/128
# 23/23 [==============================] - 0s 909us/step - loss: 8.1873e-04
# Epoch 48/128
# 23/23 [==============================] - 0s 865us/step - loss: 0.0013
# Epoch 49/128
# 23/23 [==============================] - 0s 955us/step - loss: 6.0463e-05
# Epoch 50/128
# 23/23 [==============================] - 0s 1ms/step - loss: 4.3185e-05
# Epoch 51/128
# 23/23 [==============================] - 0s 862us/step - loss: 8.4176e-05
# Epoch 52/128
# 23/23 [==============================] - 0s 909us/step - loss: 3.8895e-04
# Epoch 53/128
# 23/23 [==============================] - 0s 954us/step - loss: 4.9806e-04
# Epoch 54/128
# 23/23 [==============================] - 0s 1000us/step - loss: 2.3623e-04
# Epoch 55/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.0012
# Epoch 56/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 57/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0039
# Epoch 58/128
# 23/23 [==============================] - 0s 911us/step - loss: 0.0281
# Epoch 59/128
# 23/23 [==============================] - 0s 909us/step - loss: 7.5641e-04
# Epoch 60/128
# 23/23 [==============================] - 0s 909us/step - loss: 9.2603e-04
# Epoch 61/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.0622
# Epoch 62/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.1723
# Epoch 63/128
# 23/23 [==============================] - 0s 908us/step - loss: 0.0794
# Epoch 64/128
# 23/23 [==============================] - 0s 953us/step - loss: 0.0793
# Epoch 65/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0155
# Epoch 66/128
# 23/23 [==============================] - 0s 953us/step - loss: 0.0128
# Epoch 67/128
# 23/23 [==============================] - 0s 907us/step - loss: 2.1887
# Epoch 68/128
# 23/23 [==============================] - 0s 955us/step - loss: 2.7441
# Epoch 69/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.5442
# Epoch 70/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4258
# Epoch 71/128
# 23/23 [==============================] - 0s 954us/step - loss: 0.2314
# Epoch 72/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0942
# Epoch 73/128
# 23/23 [==============================] - 0s 956us/step - loss: 0.0298
# Epoch 74/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.0429
# Epoch 75/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0271
# Epoch 76/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 77/128
# 23/23 [==============================] - 0s 864us/step - loss: 7.5235e-04
# Epoch 78/128
# 23/23 [==============================] - 0s 908us/step - loss: 1.1970e-04
# Epoch 79/128
# 23/23 [==============================] - 0s 955us/step - loss: 6.5044e-05
# Epoch 80/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.2144e-04
# Epoch 81/128
# 23/23 [==============================] - 0s 953us/step - loss: 1.2748e-04
# Epoch 82/128
# 23/23 [==============================] - 0s 954us/step - loss: 2.9333e-05
# Epoch 83/128
# 23/23 [==============================] - 0s 1ms/step - loss: 1.0065e-05
# Epoch 84/128
# 23/23 [==============================] - 0s 953us/step - loss: 2.2694e-05
# Epoch 85/128
# 23/23 [==============================] - 0s 1ms/step - loss: 4.5894e-05
# Epoch 86/128
# 23/23 [==============================] - 0s 865us/step - loss: 1.2967e-05
# Epoch 87/128
# 23/23 [==============================] - 0s 998us/step - loss: 9.0329e-06
# Epoch 88/128
# 23/23 [==============================] - 0s 908us/step - loss: 6.2903e-06
# Epoch 89/128
# 23/23 [==============================] - 0s 953us/step - loss: 6.3750e-06
# Epoch 90/128
# 23/23 [==============================] - 0s 955us/step - loss: 8.6707e-06
# Epoch 91/128
# 23/23 [==============================] - 0s 955us/step - loss: 1.1155e-04
# Epoch 92/128
# 23/23 [==============================] - 0s 954us/step - loss: 7.4373e-06
# Epoch 93/128
# 23/23 [==============================] - 0s 864us/step - loss: 1.1578e-05
# Epoch 94/128
# 23/23 [==============================] - 0s 910us/step - loss: 1.1253e-05
# Epoch 95/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.0252e-05
# Epoch 96/128
# 23/23 [==============================] - 0s 955us/step - loss: 4.4818e-06
# Epoch 97/128
# 23/23 [==============================] - 0s 909us/step - loss: 2.8651e-06
# Epoch 98/128
# 23/23 [==============================] - 0s 1ms/step - loss: 8.5031e-06
# Epoch 99/128
# 23/23 [==============================] - 0s 955us/step - loss: 4.8412e-06
# Epoch 100/128
# 23/23 [==============================] - 0s 909us/step - loss: 7.9168e-06
# Epoch 101/128
# 23/23 [==============================] - 0s 955us/step - loss: 7.3329e-06
# Epoch 102/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.7169e-05
# Epoch 103/128
# 23/23 [==============================] - 0s 909us/step - loss: 1.8959e-05
# Epoch 104/128
# 23/23 [==============================] - 0s 955us/step - loss: 1.6846e-05
# Epoch 105/128
# 23/23 [==============================] - 0s 909us/step - loss: 7.2992e-05
# Epoch 106/128
# 23/23 [==============================] - 0s 956us/step - loss: 1.2320e-04
# Epoch 107/128
# 23/23 [==============================] - 0s 909us/step - loss: 3.2227e-05
# Epoch 108/128
# 23/23 [==============================] - 0s 909us/step - loss: 6.3326e-05
# Epoch 109/128
# 23/23 [==============================] - 0s 909us/step - loss: 5.4267e-05
# Epoch 110/128
# 23/23 [==============================] - 0s 954us/step - loss: 3.3955e-05
# Epoch 111/128
# 23/23 [==============================] - 0s 955us/step - loss: 5.9170e-04
# Epoch 112/128
# 23/23 [==============================] - 0s 908us/step - loss: 0.0024
# Epoch 113/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.0032
# Epoch 114/128
# 23/23 [==============================] - 0s 908us/step - loss: 7.0249e-04
# Epoch 115/128
# 23/23 [==============================] - 0s 909us/step - loss: 2.2575e-04
# Epoch 116/128
# 23/23 [==============================] - 0s 1ms/step - loss: 2.4595e-04
# Epoch 117/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0053
# Epoch 118/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.0972
# Epoch 119/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4841
# Epoch 120/128
# 23/23 [==============================] - 0s 953us/step - loss: 0.5753
# Epoch 121/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.1918
# Epoch 122/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.2291
# Epoch 123/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0537
# Epoch 124/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0128
# Epoch 125/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0137
# Epoch 126/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.0092
# Epoch 127/128
# 23/23 [==============================] - 0s 955us/step - loss: 4.7691e-05
# Epoch 128/128
# 23/23 [==============================] - 0s 864us/step - loss: 2.8329e-05

# %% [markdown]
# # 평가, 예측

# %%
loss = model.evaluate(x_test, y_test)
print("loss: ", loss)

y_predict = np.array(pre_data)

result = model.predict(y_predict)

print('prediction result:\n', result)
# Out:
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3952e-04
# loss:  0.0001395218714606017
# prediction result:
#  [[100.0171 ]
#  [101.01726]
#  [102.01741]
#  [103.01757]
#  [104.01772]
#  [105.01788]]
